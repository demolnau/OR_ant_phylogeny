# %%
from Bio import Phylo
import matplotlib
#import imp
tree = Phylo.read("ant_OR_Zhou_newick_format_tree.txt", "newick")

# %%
#output tree 
#print(tree)

# %%
#output tree as ascii
#Phylo.draw_ascii(tree)

# %%
tree.rooted = True
Phylo.draw(tree)

# %%
tree = tree.as_phyloxml()
tree.root.color = (128, 128, 128)
mrca = tree.common_ancestor({"name": "PbOr170"}, {"name": "LhOr59"})
mrca.color = "salmon"
#tree.clade[0, 1].color = "blue"
Phylo.draw(tree)

# %%
def get_parent(tree, child_clade):
    node_path = tree.get_path(child_clade)
    return node_path[-2]

# Select a clade
myclade = next(tree.find_clades("PbOr170"))
# Test the function
parent = get_parent(tree, myclade)
assert myclade in parent

# %%
def all_parents(tree):
    parents = {}
    for clade in tree.find_clades(order='level'):
        for child in clade:
            parents[child] = clade
    return parents

# Example
parents = all_parents(tree)
myclade = next(tree.find_clades("PbOr170"))
parent_of_myclade = parents[myclade]
assert myclade in parent_of_myclade

# %%
def lookup_by_names(tree):
    names = {}
    for clade in tree.find_clades():
        if clade.name:
            if clade.name in names:
                raise ValueError("Duplicate key: %s" % clade.name)
            names[clade.name] = clade
    return names

# %%
#tree = Phylo.read('ncbi_taxonomy.xml', 'phyloxml')
names = lookup_by_names(tree)
#for phylum in ('Apicomplexa', 'Euglenozoa', 'Fungi'):
#    print ("Phylum size: %d" %
#           len(names[phylum].get_terminals()))
print(names)
# Out:
# {'NvOr1': Clade(branch_length=0.08128226, name='NvOr1'), 'AmOr2': Clade(branch_length=0.0950781, name='AmOr2'), 'HsOrco': Clade(branch_length=0.02250818, name='HsOrco'), 'PbOr1': Clade(branch_length=0.01408621, name='PbOr1'), 'CfOrco': Clade(branch_length=0.00854296, name='CfOrco'), 'LhOr1JF': Clade(branch_length=0.03676804, name='LhOr1JF'), 'LhOr59': Clade(branch_length=0.45116424, name='LhOr59'), 'CfOr198': Clade(branch_length=0.27342524, name='CfOr198'), 'PbOr175': Clade(branch_length=0.193427, name='PbOr175'), 'HsOr205': Clade(branch_length=0.43801621, name='HsOr205'), 'PbOr165CTE': Clade(branch_length=0.217221, name='PbOr165CTE'), 'PbOr166': Clade(branch_length=0.13600108, name='PbOr166'), 'CfOr192': Clade(branch_length=0.25851297, name='CfOr192'), 'PbOr163': Clade(branch_length=0.10926406, name='PbOr163'), 'LhOr47FIX': Clade(branch_length=0.12497226, name='LhOr47FIX'), 'HsOr202': Clade(branch_length=0.18694917, name='HsOr202'), 'PbOr173': Clade(branch_length=0.21907559, name='PbOr173'), 'LhOr58': Clade(branch_length=0.18214679, name='LhOr58'), 'LhOr57': Clade(branch_length=0.15573244, name='LhOr57'), 'PbOr172': Clade(branch_length=0.10178697, name='PbOr172'), 'CfOr197': Clade(branch_length=0.13141009, name='CfOr197'), 'HsOr192': Clade(branch_length=0.20302367, name='HsOr192'), 'HsOr193': Clade(branch_length=0.1726608, name='HsOr193'), 'HsOr206': Clade(branch_length=0.134221, name='HsOr206'), 'HsOr207': Clade(branch_length=0.12337713, name='HsOr207'), 'HsOr208': Clade(branch_length=0.11774239, name='HsOr208'), 'PbOr168': Clade(branch_length=0.18460888, name='PbOr168'), 'CfOr199': Clade(branch_length=0.13923139, name='CfOr199'), 'LhOr50': Clade(branch_length=0.02753429, name='LhOr50'), 'LhOr51': Clade(branch_length=0.09231619, name='LhOr51'), 'HsOr201': Clade(branch_length=0.25612855, name='HsOr201'), 'LhOr48': Clade(branch_length=0.20142718, name='LhOr48'), 'PbOr164FIX': Clade(branch_length=0.19873381, name='PbOr164FIX'), 'LhOr49': Clade(branch_length=0.12406288, name='LhOr49'), 'PbOr167': Clade(branch_length=0.14201801, name='PbOr167'), 'HsOr199': Clade(branch_length=0.28533683, name='HsOr199'), 'AmOr169': Clade(branch_length=0.10306107, name='AmOr169'), 'AmOr168': Clade(branch_length=0.11123698, name='AmOr168'), 'AmOr170': Clade(branch_length=0.14432569, name='AmOr170'), 'HsOr194': Clade(branch_length=0.43063664, name='HsOr194'), 'CfOr196': Clade(branch_length=0.16027143, name='CfOr196'), 'LhOr54': Clade(branch_length=0.12674932, name='LhOr54'), 'LhOr56': Clade(branch_length=0.26028759, name='LhOr56'), 'HsOr200': Clade(branch_length=0.26549291, name='HsOr200'), 'HsOr197': Clade(branch_length=0.056576, name='HsOr197'), 'HsOr196': Clade(branch_length=0.081223, name='HsOr196'), 'HsOr195': Clade(branch_length=0.042494, name='HsOr195'), 'HsOr198': Clade(branch_length=0.07020891, name='HsOr198'), 'LhOr55': Clade(branch_length=0.15518797, name='LhOr55'), 'CfOr193': Clade(branch_length=0.17195907, name='CfOr193'), 'LhOr52': Clade(branch_length=0.17441157, name='LhOr52'), 'CfOr195': Clade(branch_length=0.14063719, name='CfOr195'), 'CfOr194': Clade(branch_length=0.14702594, name='CfOr194'), 'PbOr170': Clade(branch_length=0.13750166, name='PbOr170'), 'HsOr188': Clade(branch_length=0.08549801, name='HsOr188'), 'CfOr188': Clade(branch_length=0.07021215, name='CfOr188'), 'PbOr151': Clade(branch_length=0.13831566, name='PbOr151'), 'AmOr119': Clade(branch_length=0.6628484, name='AmOr119'), 'LhOr210': Clade(branch_length=0.03359019, name='LhOr210'), 'AmOr116': Clade(branch_length=0.3620751, name='AmOr116'), 'CfOr217': Clade(branch_length=0.04902603, name='CfOr217'), 'PbOr197': Clade(branch_length=0.09683217, name='PbOr197'), 'LhOr224': Clade(branch_length=0.08972857, name='LhOr224'), 'HsOr219': Clade(branch_length=0.13733509, name='HsOr219'), 'NvOr121PSE': Clade(branch_length=0.29207984, name='NvOr121PSE'), 'NvOr122': Clade(branch_length=0.62178351, name='NvOr122'), 'NvOr125': Clade(branch_length=0.47436436, name='NvOr125'), 'NvOr118':  ...

# %%
mrca = tree.common_ancestor({"name": "PbOr170"}, {"name": "LhOr59"})

# %%
tree.get_terminals()
# Out:
# [Clade(branch_length=0.08128226, name='NvOr1'),
#  Clade(branch_length=0.0950781, name='AmOr2'),
#  Clade(branch_length=0.02250818, name='HsOrco'),
#  Clade(branch_length=0.01408621, name='PbOr1'),
#  Clade(branch_length=0.00854296, name='CfOrco'),
#  Clade(branch_length=0.03676804, name='LhOr1JF'),
#  Clade(branch_length=0.45116424, name='LhOr59'),
#  Clade(branch_length=0.27342524, name='CfOr198'),
#  Clade(branch_length=0.193427, name='PbOr175'),
#  Clade(branch_length=0.43801621, name='HsOr205'),
#  Clade(branch_length=0.217221, name='PbOr165CTE'),
#  Clade(branch_length=0.13600108, name='PbOr166'),
#  Clade(branch_length=0.25851297, name='CfOr192'),
#  Clade(branch_length=0.10926406, name='PbOr163'),
#  Clade(branch_length=0.12497226, name='LhOr47FIX'),
#  Clade(branch_length=0.18694917, name='HsOr202'),
#  Clade(branch_length=0.21907559, name='PbOr173'),
#  Clade(branch_length=0.18214679, name='LhOr58'),
#  Clade(branch_length=0.15573244, name='LhOr57'),
#  Clade(branch_length=0.10178697, name='PbOr172'),
#  Clade(branch_length=0.13141009, name='CfOr197'),
#  Clade(branch_length=0.20302367, name='HsOr192'),
#  Clade(branch_length=0.1726608, name='HsOr193'),
#  Clade(branch_length=0.134221, name='HsOr206'),
#  Clade(branch_length=0.12337713, name='HsOr207'),
#  Clade(branch_length=0.11774239, name='HsOr208'),
#  Clade(branch_length=0.18460888, name='PbOr168'),
#  Clade(branch_length=0.13923139, name='CfOr199'),
#  Clade(branch_length=0.02753429, name='LhOr50'),
#  Clade(branch_length=0.09231619, name='LhOr51'),
#  Clade(branch_length=0.25612855, name='HsOr201'),
#  Clade(branch_length=0.20142718, name='LhOr48'),
#  Clade(branch_length=0.19873381, name='PbOr164FIX'),
#  Clade(branch_length=0.12406288, name='LhOr49'),
#  Clade(branch_length=0.14201801, name='PbOr167'),
#  Clade(branch_length=0.28533683, name='HsOr199'),
#  Clade(branch_length=0.10306107, name='AmOr169'),
#  Clade(branch_length=0.11123698, name='AmOr168'),
#  Clade(branch_length=0.14432569, name='AmOr170'),
#  Clade(branch_length=0.43063664, name='HsOr194'),
#  Clade(branch_length=0.16027143, name='CfOr196'),
#  Clade(branch_length=0.12674932, name='LhOr54'),
#  Clade(branch_length=0.26028759, name='LhOr56'),
#  Clade(branch_length=0.26549291, name='HsOr200'),
#  Clade(branch_length=0.056576, name='HsOr197'),
#  Clade(branch_length=0.081223, name='HsOr196'),
#  Clade(branch_length=0.042494, name='HsOr195'),
#  Clade(branch_length=0.07020891, name='HsOr198'),
#  Clade(branch_length=0.15518797, name='LhOr55'),
#  Clade(branch_length=0.17195907, name='CfOr193'),
#  Clade(branch_length=0.17441157, name='LhOr52'),
#  Clade(branch_length=0.14063719, name='CfOr195'),
#  Clade(branch_length=0.14702594, name='CfOr194'),
#  Clade(branch_length=0.13750166, name='PbOr170'),
#  Clade(branch_length=0.08549801, name='HsOr188'),
#  Clade(branch_length=0.07021215, name='CfOr188'),
#  Clade(branch_length=0.13831566, name='PbOr151'),
#  Clade(branch_length=0.6628484, name='AmOr119'),
#  Clade(branch_length=0.03359019, name='LhOr210'),
#  Clade(branch_length=0.3620751, name='AmOr116'),
#  Clade(branch_length=0.04902603, name='CfOr217'),
#  Clade(branch_length=0.09683217, name='PbOr197'),
#  Clade(branch_length=0.08972857, name='LhOr224'),
#  Clade(branch_length=0.13733509, name='HsOr219'),
#  Clade(branch_length=0.29207984, name='NvOr121PSE'),
#  Clade(branch_length=0.62178351, name='NvOr122'),
#  Clade(branch_length=0.47436436, name='NvOr125'),
#  Clade(branch_length=0.07041877, name='NvOr118'),
#  Clade(branch_length=0.09597864, name='NvOr117'),
#  Clade(branch_length=0.1217736, name='NvOr119'),
#  Clade(branch_length=0.14614724, name='NvOr124'),
#  Clade(branch_length=0.13362512, name='NvOr126'),
#  Clade(branch_length=0.11531719, name='NvOr127INT'),
#  Clade(branch_length=0.1752979, name='NvOr128'),
#  Clade(branch_length=0.0480213, name='LhOr227'),
#  Clade(branch_length=0.09799219, name='LhOr228'),
#  Clade(branch_length=0.29409941, name='HsOr181'),
#  Clade(branch_length=0.08346636, name='PbOr227'),
#  Clade(branch_length=0.03351991, name='HsOr183'),
#  Clade(branch_length=0.04949319, name='HsOr182'),
#  Clade(branch_length=0.05991391, name='PbOr229'),
#  Clade(branch_length=0.06068293, name='CfOr263'),
#  Clade(branch_length=0.05957639, name='LhOr229'),
#  Clade(branch_length=0.14080034, name='LhOr231'),
#  Clade(branch_length=0.10312948, name='CfOr258'),
#  Clade(branch_length=0.10825628, name='PbOr230'),
#  Clade(branch_length=0.15603304, name='LhOr230'),
#  Clade(branch_length=0.0485205, name='CfOr259'),
#  Clade(branch_length=0.05141553, name='CfOr261'),
#  Clade(branch_length=0.05927882, name='CfOr262'),
#  Clade(branch_length=0.67220556, name='NvOr80'),
#  Clade(branch_length=0.4809272, name='NvOr98'),
#  Clade(branch_length=0.61923833, name='NvOr103'),
#  Clade(branch_length=0.52927625, name='NvOr105'),
#  Clade(branch_length=0.55044375, name='NvOr99'),
#  Clade(branch_length=0.28734757, name='NvOr100'),
#  Clade(branch_length=0.2639695, name='NvOr102'),
#  Clade(branch_length=0.20612633, name='NvOr101'),
#  Clade(branch_length=0.36267247, name='NvOr113'),
#  Clade(branch_length=0.30567726, name='NvOr114'),
#  Clade(branch_length=0.16974056, name='NvOr115'),
#  Clade(branch_length=0.17984747, name='NvOr112PSE'),
#  Clade(branch_length=0.32927555, name='NvOr106'),
#  Clade(branch_length=0.17212195, name='NvOr108PSE'),
#  Clade(branch_length=0.17110724, name='NvOr109PSE'),
#  Clade(branch_length=0.21438926, name='NvOr107'),
#  Clade(branch_length=0.16448678, name='NvOr111'),
#  Clade(branch_length=0.17647072, name='NvOr110'),
#  Clade(branch_length=0.31301873, name='NvOr93'),
#  Clade(branch_length=1.07231547, name='NvOr90PSE'),
#  Clade(branch_length=0.45912099, name='NvOr94'),
#  Clade(branch_length=0.55949833, name='NvOr92'),
#  Clade(branch_length=0.68130917, name='NvOr96'),
#  Clade(branch_length=0.25498756, name='NvOr84INT'),
#  Clade(branch_length=0.3383861, name='NvOr85'),
#  Clade(branch_length=0.57465403, name='NvOr97CTE'),
#  Clade(branch_length=0.07917769, name='NvOr87'),
#  Clade(branch_length=0.14054243, name='NvOr86'),
#  Clade(branch_length=0.23558342, name='NvOr88'),
#  Clade(branch_length=0.22527817, name='NvOr89'),
#  Clade(branch_length=0.35978026, name='AmOr73'),
#  Clade(branch_length=0.06465506, name='CfOr218'),
#  Clade(branch_length=0.0763194, name='LhOr225'),
#  Clade(branch_length=0.12606008, name='PbOr198FIX'),
#  Clade(branch_length=0.08125804, name='PbOr199FIX'),
#  Clade(branch_length=0.01655603, name='PbOr200'),
#  Clade(branch_length=0.04270529, name='PbOr201'),
#  Clade(branch_length=0.11473615, name='LhOr226'),
#  Clade(branch_length=0.07567194, name='HsOr242'),
#  Clade(branch_length=0.14769105, name='HsOr240'),
#  Clade(branch_length=0.05496904, name='HsOr241'),
#  Clade(branch_length=0.05252207, name='CfOr231'),
#  Clade(branch_length=0.13713233, name='CfOr229'),
#  Clade(branch_length=0.05227871, name='CfOr230'),
#  Clade(branch_length=0.05619962, name='CfOr232'),
#  Clade(branch_length=0.41875063, name='NvOr82'),
#  Clade(branch_length=0.48270758, name='NvOr81'),
#  Clade(branch_length=0.1458448, name='LhOr138'),
#  Clade(branch_length=0.14805883, name='LhOr137'),
#  Clade(branch_length=0.23759688, name='HsOr239'),
#  Clade(branch_length=0.20789034, name='LhOr139'),
#  Clade(branch_length=0.20454021, name='PbOr202FIX'),
#  Clade(branch_length=0.04569808, name='CfOr233'),
#  Clade(branch_length=0.06295296, name='CfOr251'),
#  Clade(branch_length=0.0349562, name='CfOr234'),
#  Clade(branch_length=0.10050021, name='CfOr250'),
#  Clade(branch_length=0.09421744, name='HsOr235'),
#  Clade(branch_length=0.03443536, name='HsOr234'),
#  Clade(branch_length=0.04701721, name='HsOr236'),
#  Clade(branch_length=0.02624947, name='HsOr238'),
#  Clade(branch_length=0.18548113, name='CfOr257'),
#  Clade(branch_length=0.09625652, name='HsOr226'),
#  Clade(branch_length=0.10126886, name='HsOr227'),
#  Clade(branch_length=0.2261559, name='HsOr237'),
#  Clade(branch_length=0.04238056, name='HsOr230'),
#  Clade(branch_length=0.07464944, name='HsOr231'),
#  Clade(branch_length=0.03120448, name='HsOr228'),
#  Clade(branch_length=0.06896435, name='HsOr229'),
#  Clade(branch_length=0.07838483, name='HsOr232'),
#  Clade(branch_length=0.01026736, name='HsOr233'),
#  Clade(branch_length=0.16071458, name='PbOr206FIX'),
#  Clade(branch_length=0.1158931, name='CfOr255'),
#  Clade(branch_length=0.10268166, name='CfOr249'),
#  Clade(branch_length=0.13239061, name='LhOr140FIX'),
#  Clade(branch_length=0.05728814, name='CfOr252'),
#  Clade(branch_length=0.05106616, name='PbOr203'),
#  Clade(branch_length=0.1733139, name='CfOr254'),
#  Clade(branch_length=0.05688793, name='LhOr142'),
#  Clade(branch_length=0.06044113, name='LhOr141'),
#  Clade(branch_length=0.18001099, name='PbOr207'),
#  Clade(branch_length=0.15905481, name='LhOr145'),
#  Clade(branch_length=0.1092024, name='LhOr143'),
#  Clade(branch_length=0.2761876, name='LhOr144'),
#  Clade(branch_length=0.44031275, name='AmOr70'),
#  Clade(branch_length=0.3747756, name='AmOr71'),
#  Clade(branch_length=0.66691215, name='AmOr72'),
#  Clade(branch_length=0.53618641, name='AmOr68'),
#  Clade(branch_length=0.53457315, name='AmOr69'),
#  Clade(branch_length=0.1558148, name='LhOr123FIX'),
#  Clade(branch_length=0.09970991, name='CfOr243'),
#  Clade(branch_length=0.14662012, name='CfOr244'),
#  Clade(branch_length=0.00324599, name='LhOr124'),
#  Clade(branch_length=0.01047542, name='LhOr125'),
#  Clade(branch_length=0.15256636, name='CfOr245'),
#  Clade(branch_length=0.15746285, name='PbOr214'),
#  Clade(branch_length=0.10681072, name='PbOr213'),
#  Clade(branch_length=0.04467212, name='CfOr242'),
#  Clade(branch_length=0.05840018, name='LhOr122'),
#  Clade(branch_length=0.05625076, name='CfOr239'),
#  Clade(branch_length=0.07069208, name='LhOr119'),
#  Clade(branch_length=0.07838268, name='LhOr118'),
#  Clade(branch_length=0.125538, name='CfOr238'),
#  Clade(branch_length=0.08447558, name='PbOr209'),
#  Clade(branch_length=0.06392648, name='PbOr210'),
#  Clade(branch_length=0.12860265, name='CfOr236'),
#  Clade(branch_length=0.11786002, name='LhOr117'),
#  Clade(branch_length=0.06396234, name='CfOr241'),
#  Clade(branch_length=0.06611946, name='LhOr121'),
#  Clade(branch_length=0.11927267, name='PbOr212'),
#  Clade(branch_length=0.06701255, name='LhOr120FIX'),
#  Clade(branch_length=0.06629987, name='CfOr240'),
#  Clade(branch_length=0.06664293, name='PbOr211JF'),
#  Clade(branch_length=0.07278616, name='LhOr126'),
#  Clade(branch_length=0.06146297, name='PbOr215'),
#  Clade(branch_length=0.02487883, name='CfOr246'),
#  Clade(branch_length=0.00955277, name='CfOr247'),
#  Clade(branch_length=0.04485538, name='CfOr248'),
#  Clade(branch_length=0.10486396, name='LhOr128'),
#  Clade(branch_length=0.17345113, name='CfOr226'),
#  Clade(branch_length=0.14726656, name='PbOr217FIX'),
#  Clade(branch_length=0.10390898, name='LhOr127'),
#  Clade(branch_length=0.03944125, name='CfOr227'),
#  Clade(branch_length=0.01225209, name='CfOr228'),
#  Clade(branch_length=0.11709031, name='CfOr224'),
#  Clade(branch_length=0.23091504, name='HsOr220'),
#  Clade(branch_length=0.17021303, name='LhOr129'),
#  Clade(branch_length=0.15887589, name='HsOr221'),
#  Clade(branch_length=0.06989033, name='CfOr222'),
#  Clade(branch_length=0.12279723, name='LhOr130'),
#  Clade(branch_length=0.17756509, name='CfOr223'),
#  Clade(branch_length=0.10681, name='LhOr131'),
#  Clade(branch_length=0.09452082, name='PbOr221'),
#  Clade(branch_length=0.00656245, name='PbOr219'),
#  Clade(branch_length=0.02537651, name='PbOr220'),
#  Clade(branch_length=0.05518604, name='CfOr225'),
#  Clade(branch_length=0.10661893, name='PbOr218'),
#  Clade(branch_length=0.41328409, name='HsOr224'),
#  Clade(branch_length=0.16609289, name='LhOr132'),
#  Clade(branch_length=0.14204464, name='PbOr222FIX'),
#  Clade(branch_length=0.02882807, name='CfOr219'),
#  Clade(branch_length=0.0783626, name='CfOr220'),
#  Clade(branch_length=0.26114281, name='HsOr225'),
#  Clade(branch_length=0.15911383, name='LhOr133'),
#  Clade(branch_length=0.19013043, name='PbOr223JOI'),
#  Clade(branch_length=0.1250681, name='LhOr136'),
#  Clade(branch_length=0.0699956, name='PbOr225'),
#  Clade(branch_length=0.14732434, name='HsOr223'),
#  Clade(branch_length=0.07799627, name='PbOr224JOI'),
#  Clade(branch_length=0.06447139, name='LhOr134FIX'),
#  Clade(branch_length=0.10813083, name='LhOr135'),
#  Clade(branch_length=0.56939849, name='NvOr261'),
#  Clade(branch_length=0.3818421, name='NvOr242'),
#  Clade(branch_length=0.39313436, name='NvOr248'),
#  Clade(branch_length=0.21772548, name='NvOr246'),
#  Clade(branch_length=0.19280717, name='NvOr249'),
#  Clade(branch_length=0.22706674, name='NvOr255'),
#  Clade(branch_length=0.30744691, name='NvOr260'),
#  Clade(branch_length=0.05976221, name='NvOr256'),
#  Clade(branch_length=0.07101791, name='NvOr257'),
#  Clade(branch_length=0.05540839, name='NvOr258'),
#  Clade(branch_length=0.04945044, name='NvOr252'),
#  Clade(branch_length=0.05466591, name='NvOr251'),
#  Clade(branch_length=0.19640482, name='NvOr253'),
#  Clade(branch_length=0.0671731, name='NvOr247'),
#  Clade(branch_length=0.01827891, name='NvOr250'),
#  Clade(branch_length=0.17012438, name='NvOr245'),
#  Clade(branch_length=0.12110594, name='NvOr243'),
#  Clade(branch_length=0.01873719, name='NvOr241'),
#  Clade(branch_length=0.03328487, name='NvOr262'),
#  Clade(branch_length=0.04831761, name='NvOr263'),
#  Clade(branch_length=0.79674056, name='AmOr171'),
#  Clade(branch_length=0.22697427, name='HsOr191'),
#  Clade(branch_length=0.13807643, name='LhOr214'),
#  Clade(branch_length=0.24959498, name='CfOr191'),
#  Clade(branch_length=0.17621167, name='PbOr155'),
#  Clade(branch_length=0.23724203, name='PbOr162'),
#  Clade(branch_length=0.18710164, name='PbOr161FI'),
#  Clade(branch_length=0.19568788, name='PbOr156FIX'),
#  Clade(branch_length=0.10022992, name='PbOr160FIX'),
#  Clade(branch_length=0.08904585, name='PbOr159FIX'),
#  Clade(branch_length=0.06372153, name='PbOr157'),
#  Clade(branch_length=0.04677104, name='PbOr158FIX'),
#  Clade(branch_length=0.27800499, name='NvOr285'),
#  Clade(branch_length=0.40097089, name='NvOr286'),
#  Clade(branch_length=0.22167437, name='NvOr264'),
#  Clade(branch_length=0.09086199, name='NvOr265'),
#  Clade(branch_length=0.14713464, name='NvOr266'),
#  Clade(branch_length=0.09136073, name='NvOr269'),
#  Clade(branch_length=0.12418854, name='NvOr267'),
#  Clade(branch_length=0.05975925, name='NvOr268'),
#  Clade(branch_length=0.21959041, name='NvOr276'),
#  Clade(branch_length=0.43754714, name='NvOr275'),
#  Clade(branch_length=0.16942202, name='NvOr273'),
#  Clade(branch_length=0.03201817, name='NvOr271'),
#  Clade(branch_length=0.00728968, name='NvOr272'),
#  Clade(branch_length=0.44381193, name='NvOr283'),
#  Clade(branch_length=0.27776694, name='NvOr277'),
#  Clade(branch_length=0.29786615, name='NvOr280'),
#  Clade(branch_length=0.0947539, name='NvOr278'),
#  Clade(branch_length=0.03983537, name='NvOr279'),
#  Clade(branch_length=0.04796793, name='NvOr281'),
#  Clade(branch_length=0.92181448, name='NvOr295'),
#  Clade(branch_length=0.68099848, name='NvOr293'),
#  Clade(branch_length=0.44186144, name='NvOr294'),
#  Clade(branch_length=0.68319469, name='NvOr47'),
#  Clade(branch_length=0.61378263, name='NvOr48'),
#  Clade(branch_length=0.61356749, name='NvOr56'),
#  Clade(branch_length=0.51951949, name='NvOr53'),
#  Clade(branch_length=0.42623532, name='NvOr50'),
#  Clade(branch_length=0.62071746, name='NvOr51'),
#  Clade(branch_length=0.52520324, name='NvOr59'),
#  Clade(branch_length=0.45523567, name='NvOr58'),
#  Clade(branch_length=0.88648926, name='NvOr43'),
#  Clade(branch_length=0.82489189, name='NvOr46'),
#  Clade(branch_length=0.59282144, name='HsOr215'),
#  Clade(branch_length=0.27219408, name='PbOr191FIX'),
#  Clade(branch_length=0.2210623, name='CfOr211'),
#  Clade(branch_length=0.65021958, name='NvOr45'),
#  Clade(branch_length=0.05217756, name='AmOr143'),
#  Clade(branch_length=0.0132125, name='AmOr144'),
#  Clade(branch_length=0.08772903, name='AmOr145'),
#  Clade(branch_length=0.0675207, name='PbOr196JF'),
#  Clade(branch_length=0.18388282, name='CfOr201'),
#  Clade(branch_length=0.1122305, name='LhOr223JOI'),
#  Clade(branch_length=0.49549749, name='PbOr181'),
#  Clade(branch_length=0.15456958, name='PbOr194JF'),
#  Clade(branch_length=0.09355913, name='CfOr202'),
#  Clade(branch_length=0.04786857, name='LhOr221IC'),
#  Clade(branch_length=0.24576863, name='PbOr193JOI'),
#  Clade(branch_length=0.19308372, name='CfOr204'),
#  Clade(branch_length=0.24541512, name='LhOr222'),
#  Clade(branch_length=0.11011633, name='PbOr195JF'),
#  Clade(branch_length=0.62549537, name='NvOr44'),
#  Clade(branch_length=0.337243, name='AmOr142'),
#  Clade(branch_length=0.1207536, name='CfOr205'),
#  Clade(branch_length=0.17307107, name='PbOr176'),
#  Clade(branch_length=0.10381025, name='LhOr215'),
#  Clade(branch_length=0.24395305, name='CfOr208'),
#  Clade(branch_length=0.02191473, name='LhOr218'),
#  Clade(branch_length=0.05827553, name='LhOr219IX'),
#  Clade(branch_length=0.2957403, name='CfOr207'),
#  Clade(branch_length=0.19719447, name='PbOr177'),
#  Clade(branch_length=0.2979659, name='PbOr185'),
#  Clade(branch_length=0.12923725, name='HsOr210'),
#  Clade(branch_length=0.1703209, name='HsOr211'),
#  Clade(branch_length=0.22218737, name='PbOr184NEW'),
#  Clade(branch_length=0.20582294, name='CfOr209'),
#  Clade(branch_length=0.16585139, name='HsOr212'),
#  Clade(branch_length=0.1351615, name='PbOr192'),
#  Clade(branch_length=0.08196766, name='PbOr182NEW'),
#  Clade(branch_length=0.10268354, name='LhOr220'),
#  Clade(branch_length=0.12159911, name='CfOr200'),
#  Clade(branch_length=0.07976078, name='HsOr217'),
#  Clade(branch_length=0.16604575, name='HsOr218'),
#  Clade(branch_length=0.12308702, name='HsOr209'),
#  Clade(branch_length=0.5219652, name='AmOr146'),
#  Clade(branch_length=0.12587355, name='AmOr150FIX'),
#  Clade(branch_length=0.10889675, name='AmOr152'),
#  Clade(branch_length=0.0747691, name='AmOr151'),
#  Clade(branch_length=0.22699383, name='AmOr149FIX'),
#  Clade(branch_length=0.08362998, name='AmOr154'),
#  Clade(branch_length=0.12329349, name='AmOr155JOI'),
#  Clade(branch_length=0.38716161, name='AmOr156'),
#  Clade(branch_length=0.40015582, name='AmOr157'),
#  Clade(branch_length=0.15799133, name='AmOr147FIX'),
#  Clade(branch_length=0.10726593, name='AmOr148'),
#  Clade(branch_length=0.11673595, name='AmOr158FIX'),
#  Clade(branch_length=0.24721333, name='PbOr189'),
#  Clade(branch_length=0.21869859, name='HsOr213'),
#  Clade(branch_length=0.16937703, name='PbOr187'),
#  Clade(branch_length=0.18353011, name='LhOr217FIX'),
#  Clade(branch_length=0.15289248, name='CfOr215'),
#  Clade(branch_length=0.07750327, name='PbOr180'),
#  Clade(branch_length=0.11576474, name='LhOr216'),
#  Clade(branch_length=0.14904562, name='PbOr188FIX'),
#  Clade(branch_length=0.08798331, name='HsOr214'),
#  Clade(branch_length=0.07705862, name='CfOr214'),
#  Clade(branch_length=0.13360114, name='PbOr179'),
#  Clade(branch_length=0.39776973, name='CfOr212'),
#  Clade(branch_length=0.1790034, name='CfOr213'),
#  Clade(branch_length=0.19052, name='PbOr178'),
#  Clade(branch_length=0.13335864, name='HsOr216'),
#  Clade(branch_length=0.08705516, name='PbOr190FIX'),
#  Clade(branch_length=0.4548805, name='NvOr79'),
#  Clade(branch_length=0.34422622, name='NvOr78'),
#  Clade(branch_length=1.57243003, name='NvOr300'),
#  Clade(branch_length=0.15546945, name='LhOr249'),
#  Clade(branch_length=0.19920428, name='PbOr247'),
#  Clade(branch_length=0.14026799, name='CfOr299'),
#  Clade(branch_length=0.2408965, name='PbOr248FIX'),
#  Clade(branch_length=0.14682029, name='PbOr250'),
#  Clade(branch_length=0.1864458, name='LhOr250'),
#  Clade(branch_length=0.19945352, name='PbOr255'),
#  Clade(branch_length=0.1414048, name='PbOr254'),
#  Clade(branch_length=0.0327943, name='PbOr252'),
#  Clade(branch_length=0.04531484, name='PbOr253'),
#  Clade(branch_length=0.19569334, name='PbOr251'),
#  Clade(branch_length=0.02647705, name='PbOr257FC'),
#  Clade(branch_length=0.05225909, name='PbOr258FIX'),
#  Clade(branch_length=9.4e-07, name='PbOr259'),
#  Clade(branch_length=0.27200431, name='PbOr241'),
#  Clade(branch_length=0.08807372, name='HsOr255'),
#  Clade(branch_length=0.09886512, name='LhOr238'),
#  Clade(branch_length=0.0459749, name='PbOr242'),
#  Clade(branch_length=0.00554501, name='CfOr366'),
#  Clade(branch_length=0.00256607, name='CfOr365'),
#  Clade(branch_length=0.10418645, name='LhOr232'),
#  Clade(branch_length=0.07211354, name='PbOr233'),
#  Clade(branch_length=0.21719366, name='PbOr234'),
#  Clade(branch_length=0.04058801, name='CfOr272'),
#  Clade(branch_length=0.04847248, name='CfOr271'),
#  Clade(branch_length=0.07632378, name='LhOr234'),
#  Clade(branch_length=0.14570015, name='LhOr235'),
#  Clade(branch_length=0.2546659, name='PbOr237'),
#  Clade(branch_length=0.12635044, name='PbOr240'),
#  Clade(branch_length=0.10746366, name='LhOr254FIX'),
#  Clade(branch_length=0.11647466, name='LhOr256'),
#  Clade(branch_length=0.13399977, name='PbOr264'),
#  Clade(branch_length=0.2789723, name='HsOr246'),
#  Clade(branch_length=0.48317584, name='PbOr266'),
#  Clade(branch_length=0.11407869, name='LhOr257'),
#  Clade(branch_length=0.13959303, name='HsOr243'),
#  Clade(branch_length=0.25266574, name='LhOr255'),
#  Clade(branch_length=0.08702694, name='LhOr261'),
#  Clade(branch_length=0.07757909, name='LhOr259'),
#  Clade(branch_length=0.2075353, name='PbOr265FC'),
#  Clade(branch_length=0.18699204, name='LhOr243'),
#  Clade(branch_length=0.23039439, name='LhOr244'),
#  Clade(branch_length=0.2951737, name='LhOr260FIX'),
#  Clade(branch_length=0.27489345, name='LhOr241'),
#  Clade(branch_length=0.15526267, name='LhOr242'),
#  Clade(branch_length=0.42194463, name='NvOr204'),
#  Clade(branch_length=0.58151526, name='NvOr202'),
#  Clade(branch_length=0.35228391, name='NvOr203'),
#  Clade(branch_length=0.09313291, name='NvOr198'),
#  Clade(branch_length=0.14803571, name='NvOr201'),
#  Clade(branch_length=0.25592417, name='NvOr191'),
#  Clade(branch_length=0.22731968, name='NvOr192'),
#  Clade(branch_length=0.55151177, name='NvOr196'),
#  Clade(branch_length=0.36137054, name='NvOr194'),
#  Clade(branch_length=0.07376725, name='NvOr193'),
#  Clade(branch_length=0.14628978, name='NvOr195'),
#  Clade(branch_length=0.99232243, name='NvOr207'),
#  Clade(branch_length=0.43554423, name='NvOr160'),
#  Clade(branch_length=0.47832011, name='NvOr161'),
#  Clade(branch_length=0.64392042, name='NvOr301FIX'),
#  Clade(branch_length=0.33266722, name='NvOr216'),
#  Clade(branch_length=0.47736362, name='NvOr217'),
#  Clade(branch_length=0.36444673, name='NvOr173'),
#  Clade(branch_length=0.42332644, name='NvOr175'),
#  Clade(branch_length=0.50005046, name='NvOr187'),
#  Clade(branch_length=0.39458956, name='NvOr188'),
#  Clade(branch_length=0.11356642, name='NvOr189'),
#  Clade(branch_length=0.14269872, name='NvOr190'),
#  Clade(branch_length=0.14807115, name='NvOr181'),
#  Clade(branch_length=0.3547281, name='NvOr183'),
#  Clade(branch_length=0.22841707, name='NvOr180'),
#  Clade(branch_length=0.15291562, name='NvOr179'),
#  Clade(branch_length=0.12459308, name='NvOr177'),
#  Clade(branch_length=0.17308134, name='NvOr182'),
#  Clade(branch_length=0.08802451, name='NvOr165JOI'),
#  Clade(branch_length=0.00291554, name='NvOr162'),
#  Clade(branch_length=0.02169164, name='NvOr163'),
#  Clade(branch_length=0.08847962, name='NvOr159'),
#  Clade(branch_length=0.07277307, name='NvOr156'),
#  Clade(branch_length=0.20507669, name='NvOr158'),
#  Clade(branch_length=0.13529631, name='NvOr154'),
#  Clade(branch_length=0.15595446, name='NvOr157'),
#  Clade(branch_length=0.03837828, name='NvOr155INT'),
#  Clade(branch_length=0.27739401, name='NvOr166'),
#  Clade(branch_length=0.4002495, name='NvOr167'),
#  Clade(branch_length=0.39763663, name='NvOr168'),
#  Clade(branch_length=0.70100152, name='NvOr169INT'),
#  Clade(branch_length=0.32243711, name='NvOr170'),
#  Clade(branch_length=0.36992063, name='NvOr147'),
#  Clade(branch_length=0.40384596, name='NvOr151'),
#  Clade(branch_length=0.39205368, name='NvOr150CTE'),
#  Clade(branch_length=0.16679388, name='NvOr145'),
#  Clade(branch_length=0.19252633, name='NvOr146'),
#  Clade(branch_length=0.03677143, name='NvOr149'),
#  Clade(branch_length=0.04351263, name='NvOr153'),
#  Clade(branch_length=0.45304372, name='NvOr135'),
#  Clade(branch_length=0.48511279, name='NvOr129'),
#  Clade(branch_length=0.12326526, name='NvOr133'),
#  Clade(branch_length=0.14298872, name='NvOr132'),
#  Clade(branch_length=0.19915635, name='NvOr130'),
#  Clade(branch_length=0.11698681, name='NvOr134'),
#  Clade(branch_length=0.30126363, name='NvOr140'),
#  Clade(branch_length=0.218067, name='NvOr142'),
#  Clade(branch_length=0.31603574, name='NvOr143'),
#  Clade(branch_length=0.48616223, name='NvOr141'),
#  Clade(branch_length=0.09764704, name='NvOr139'),
#  Clade(branch_length=0.06071298, name='NvOr137'),
#  Clade(branch_length=0.08261847, name='NvOr138INT'),
#  Clade(branch_length=0.87669279, name='NvOr211'),
#  Clade(branch_length=0.40602441, name='AmOr105'),
#  Clade(branch_length=0.2266353, name='AmOr98'),
#  Clade(branch_length=0.09765903, name='AmOr104'),
#  Clade(branch_length=0.0201941, name='AmOr99'),
#  Clade(branch_length=0.0129528, name='AmOr101'),
#  Clade(branch_length=0.02036059, name='AmOr102'),
#  Clade(branch_length=0.03179369, name='AmOr103'),
#  Clade(branch_length=0.05562468, name='HsOr245'),
#  Clade(branch_length=0.08774322, name='LhOr262'),
#  Clade(branch_length=0.06156898, name='PbOr267'),
#  Clade(branch_length=0.0846078, name='LhOr337'),
#  Clade(branch_length=0.09341186, name='PbOr269'),
#  Clade(branch_length=0.13201006, name='HsOr244'),
#  Clade(branch_length=0.13652327, name='CfOr341'),
#  Clade(branch_length=0.07860739, name='LhOr263'),
#  Clade(branch_length=0.07909048, name='PbOr268'),
#  Clade(branch_length=0.2127293, name='PbOr263'),
#  Clade(branch_length=0.12764548, name='LhOr253'),
#  Clade(branch_length=0.00410687, name='HsOr305'),
#  Clade(branch_length=0.09757743, name='HsOr304'),
#  Clade(branch_length=0.0404233, name='HsOr303'),
#  Clade(branch_length=0.13557253, name='LhOr252'),
#  Clade(branch_length=0.05410281, name='CfOr276'),
#  Clade(branch_length=0.07063723, name='CfOr330'),
#  Clade(branch_length=0.01566688, name='PbOr262'),
#  Clade(branch_length=0.02602159, name='PbOr261'),
#  Clade(branch_length=0.16709483, name='PbOr260FIX'),
#  Clade(branch_length=0.20766917, name='CfOr297'),
#  Clade(branch_length=0.04231595, name='CfOr274'),
#  Clade(branch_length=0.0788042, name='CfOr360'),
#  Clade(branch_length=0.03904948, name='CfOr275'),
#  Clade(branch_length=0.28306621, name='PbOr244'),
#  Clade(branch_length=0.11887513, name='LhOr239'),
#  Clade(branch_length=0.05623286, name='LhOr240'),
#  Clade(branch_length=0.72230425, name='AmOr140NTE'),
#  Clade(branch_length=0.10929362, name='LhOr245'),
#  Clade(branch_length=0.13796605, name='CfOr267'),
#  Clade(branch_length=0.35298697, name='LhOr367'),
#  Clade(branch_length=0.1479746, name='PbOr382'),
#  Clade(branch_length=0.1379449, name='HsOr370'),
#  Clade(branch_length=0.09387106, name='CfOr300'),
#  Clade(branch_length=0.08965422, name='CfOr265'),
#  Clade(branch_length=0.1176828, name='CfOr345'),
#  Clade(branch_length=0.15154638, name='LhOr246'),
#  Clade(branch_length=0.10614656, name='CfOr266'),
#  Clade(branch_length=0.04434517, name='PbOr245FIX'),
#  Clade(branch_length=0.03346284, name='PbOr246'),
#  Clade(branch_length=0.14779466, name='PbOr369FNC'),
#  Clade(branch_length=0.13134522, name='PbOr372'),
#  Clade(branch_length=0.30011419, name='HsOr262'),
#  Clade(branch_length=0.21424753, name='LhOr360FIX'),
#  Clade(branch_length=0.11888686, name='LhOr356'),
#  Clade(branch_length=0.12741001, name='LhOr355'),
#  Clade(branch_length=0.09930395, name='LhOr357'),
#  Clade(branch_length=0.0854467, name='LhOr358'),
#  Clade(branch_length=0.1306949, name='LhOr365'),
#  Clade(branch_length=0.17435604, name='LhOr366'),
#  Clade(branch_length=0.10134298, name='PbOr381FIX'),
#  Clade(branch_length=0.26202987, name='PbOr375INT'),
#  Clade(branch_length=0.26604876, name='PbOr376FI'),
#  Clade(branch_length=0.14097668, name='PbOr380'),
#  Clade(branch_length=0.12392466, name='PbOr378FI'),
#  Clade(branch_length=0.12855732, name='PbOr377'),
#  Clade(branch_length=0.03791492, name='PbOr379INT'),
#  Clade(branch_length=0.13389882, name='HsOr261'),
#  Clade(branch_length=0.08456436, name='PbOr373FIX'),
#  Clade(branch_length=0.09667892, name='CfOr389'),
#  Clade(branch_length=0.16360175, name='LhOr361'),
#  Clade(branch_length=0.08935156, name='HsOr260'),
#  Clade(branch_length=0.12239284, name='CfOr388'),
#  Clade(branch_length=0.07272704, name='PbOr374'),
#  Clade(branch_length=9.4e-07, name='LhOr362FIX'),
#  Clade(branch_length=0.18443593, name='LhOr363'),
#  Clade(branch_length=0.00233392, name='LhOr364FIX'),
#  Clade(branch_length=0.55255663, name='AmOr106'),
#  Clade(branch_length=0.50654487, name='AmOr112'),
#  Clade(branch_length=0.44941023, name='AmOr113'),
#  Clade(branch_length=0.2708, name='AmOr107'),
#  Clade(branch_length=0.04805756, name='AmOr111'),
#  Clade(branch_length=0.12643009, name='AmOr108'),
#  Clade(branch_length=0.06033174, name='AmOr109'),
#  Clade(branch_length=0.10243319, name='AmOr110FIX'),
#  Clade(branch_length=0.48815246, name='LhOr349'),
#  Clade(branch_length=0.03137815, name='HsOr258'),
#  Clade(branch_length=0.07937989, name='HsOr257'),
#  Clade(branch_length=0.0228495, name='HsOr259'),
#  Clade(branch_length=0.02131812, name='HsOr354'),
#  Clade(branch_length=0.1942974, name='PbOr274'),
#  Clade(branch_length=0.12073343, name='CfOr279'),
#  Clade(branch_length=0.2857019, name='CfOr280'),
#  Clade(branch_length=0.09373578, name='CfOr281'),
#  Clade(branch_length=0.2370117, name='CfOr286'),
#  Clade(branch_length=0.21372988, name='HsOr367'),
#  Clade(branch_length=0.24905218, name='HsOr368'),
#  Clade(branch_length=0.045201, name='HsOr365'),
#  Clade(branch_length=0.06918092, name='HsOr364'),
#  Clade(branch_length=0.0420716, name='HsOr366'),
#  Clade(branch_length=0.26482616, name='PbOr280'),
#  Clade(branch_length=0.15383724, name='PbOr275'),
#  Clade(branch_length=0.11271876, name='PbOr277FIX'),
#  Clade(branch_length=0.13824224, name='CfOr283'),
#  Clade(branch_length=0.0847779, name='CfOr292'),
#  Clade(branch_length=0.16119563, name='CfOr288'),
#  Clade(branch_length=0.11969033, name='CfOr291'),
#  Clade(branch_length=0.07832736, name='CfOr289'),
#  Clade(branch_length=0.05297298, name='CfOr290'),
#  Clade(branch_length=0.05825935, name='HsOr362'),
#  Clade(branch_length=0.08728375, name='HsOr363'),
#  Clade(branch_length=0.09516012, name='PbOr271'),
#  Clade(branch_length=0.09365646, name='CfOr391'),
#  Clade(branch_length=0.16319165, name='LhOr348'),
#  Clade(branch_length=0.09937379, name='CfOr390'),
#  Clade(branch_length=0.13004272, name='PbOr273'),
#  Clade(branch_length=0.15722689, name='LhOr345'),
#  Clade(branch_length=0.2609396, name='LhOr346'),
#  Clade(branch_length=0.10902558, name='LhOr347'),
#  Clade(branch_length=0.09372435, name='PbOr272'),
#  Clade(branch_length=0.09343466, name='HsOr359'),
#  Clade(branch_length=0.10532062, name='HsOr358'),
#  Clade(branch_length=0.17277654, name='HsOr361'),
#  Clade(branch_length=0.12296904, name='HsOr256'),
#  Clade(branch_length=0.28184281, name='HsOr353'),
#  Clade(branch_length=0.20096138, name='HsOr355'),
#  Clade(branch_length=0.34134456, name='HsOr356'),
#  Clade(branch_length=0.06302361, name='LhOr342'),
#  Clade(branch_length=0.12102051, name='LhOr343'),
#  Clade(branch_length=0.12885902, name='PbOr279'),
#  Clade(branch_length=0.06102344, name='CfOr282'),
#  Clade(branch_length=0.08504822, name='CfOr284'),
#  Clade(branch_length=0.06964957, name='CfOr285'),
#  Clade(branch_length=0.03715262, name='CfOr287'),
#  Clade(branch_length=0.17665645, name='LhOr338'),
#  Clade(branch_length=0.17506549, name='PbOr270'),
#  Clade(branch_length=0.12851366, name='CfOr392'),
#  Clade(branch_length=0.02128273, name='LhOr341'),
#  Clade(branch_length=0.04794505, name='LhOr339FIX'),
#  Clade(branch_length=0.02601358, name='LhOr340FIX'),
#  Clade(branch_length=0.2823832, name='CfOr343'),
#  Clade(branch_length=0.26165378, name='LhOr350'),
#  Clade(branch_length=0.16769915, name='PbOr232FIX'),
#  Clade(branch_length=0.28084478, name='PbOr231'),
#  Clade(branch_length=0.40146286, name='CfOr344'),
#  Clade(branch_length=0.43211843, name='HsOr369'),
#  Clade(branch_length=0.15402885, name='CfOr268'),
#  Clade(branch_length=0.26494117, name='LhOr233'),
#  Clade(branch_length=0.17761909, name='PbOr383'),
#  Clade(branch_length=0.03980306, name='PbOr389NC'),
#  Clade(branch_length=0.01631264, name='PbOr388NTE'),
#  Clade(branch_length=0.00839045, name='PbOr384FN'),
#  Clade(branch_length=0.02780918, name='PbOr386NC'),
#  Clade(branch_length=0.00373249, name='PbOr387FN'),
#  Clade(branch_length=0.26287075, name='LhOr325'),
#  Clade(branch_length=0.28145645, name='HsOr342'),
#  Clade(branch_length=0.49849064, name='HsOr312'),
#  Clade(branch_length=0.2060907, name='HsOr313'),
#  Clade(branch_length=0.15697712, name='CfOr396'),
#  Clade(branch_length=0.24340839, name='LhOr316'),
#  Clade(branch_length=0.35306772, name='PbOr317FI'),
#  Clade(branch_length=0.12132746, name='LhOr317'),
#  Clade(branch_length=0.10435657, name='CfOr395'),
#  Clade(branch_length=0.14389075, name='PbOr318FC'),
#  Clade(branch_length=0.08980189, name='CfOr356'),
#  Clade(branch_length=0.1573859, name='PbOr303'),
#  Clade(branch_length=0.15139614, name='HsOr343'),
#  Clade(branch_length=0.22704462, name='HsOr344'),
#  Clade(branch_length=0.07208773, name='CfOr354'),
#  Clade(branch_length=0.13730837, name='CfOr355'),
#  Clade(branch_length=0.15578514, name='LhOr326'),
#  Clade(branch_length=0.04462189, name='PbOr301'),
#  Clade(branch_length=0.02264934, name='PbOr302FIX'),
#  Clade(branch_length=0.15572275, name='CfOr358'),
#  Clade(branch_length=0.14100247, name='HsOr345'),
#  Clade(branch_length=0.47327552, name='HsOr349'),
#  Clade(branch_length=0.11166744, name='PbOr307'),
#  Clade(branch_length=0.12690705, name='PbOr323FIX'),
#  Clade(branch_length=0.24369815, name='CfOr359'),
#  Clade(branch_length=0.23840969, name='LhOr332'),
#  Clade(branch_length=0.27272672, name='HsOr346'),
#  Clade(branch_length=0.00989235, name='HsOr263'),
#  Clade(branch_length=0.0034131, name='HsOr347'),
#  Clade(branch_length=0.01499681, name='HsOr348'),
#  Clade(branch_length=0.24619001, name='CfOr357'),
#  Clade(branch_length=0.10299391, name='PbOr304FIX'),
#  Clade(branch_length=0.12460888, name='PbOr305'),
#  Clade(branch_length=0.0865521, name='PbOr322'),
#  Clade(branch_length=0.26084519, name='LhOr331'),
#  Clade(branch_length=0.1247535, name='LhOr327'),
#  Clade(branch_length=0.17365243, name='LhOr328'),
#  Clade(branch_length=0.14139577, name='LhOr329'),
#  Clade(branch_length=0.09963636, name='LhOr330'),
#  Clade(branch_length=0.75357702, name='LhOr333'),
#  Clade(branch_length=0.29287928, name='PbOr319'),
#  Clade(branch_length=0.13158936, name='CfOr397'),
#  Clade(branch_length=0.12842167, name='LhOr315'),
#  Clade(branch_length=0.20475138, name='HsOr314'),
#  Clade(branch_length=0.22951934, name='HsOr350'),
#  Clade(branch_length=0.12288705, name='LhOr334'),
#  Clade(branch_length=0.1726913, name='PbOr309'),
#  Clade(branch_length=0.11932386, name='CfOr363'),
#  Clade(branch_length=0.03115425, name='CfOr361'),
#  Clade(branch_length=0.02086923, name='CfOr362'),
#  Clade(branch_length=0.09606056, name='PbOr315'),
#  Clade(branch_length=0.00549672, name='PbOr312FIX'),
#  Clade(branch_length=0.00533593, name='PbOr313FIX'),
#  Clade(branch_length=0.03569839, name='PbOr311'),
#  Clade(branch_length=0.02103017, name='PbOr314'),
#  Clade(branch_length=0.9850891, name='AmOr159NTE'),
#  Clade(branch_length=0.54288703, name='HsOr351'),
#  Clade(branch_length=0.35541796, name='PbOr316'),
#  Clade(branch_length=0.39813871, name='CfOr364'),
#  Clade(branch_length=0.33246884, name='LhOr336'),
#  Clade(branch_length=0.26350414, name='HsOr315'),
#  Clade(branch_length=0.12797239, name='HsOr318'),
#  Clade(branch_length=0.02544465, name='HsOr317'),
#  Clade(branch_length=0.03869769, name='HsOr321'),
#  Clade(branch_length=0.13351635, name='HsOr322'),
#  Clade(branch_length=0.03424553, name='HsOr320'),
#  Clade(branch_length=0.03244853, name='HsOr319'),
#  Clade(branch_length=0.04458818, name='HsOr316'),
#  Clade(branch_length=0.2128812, name='HsOr324'),
#  Clade(branch_length=0.14827586, name='CfOr398'),
#  Clade(branch_length=0.2231424, name='LhOr314'),
#  Clade(branch_length=0.30371999, name='PbOr320'),
#  Clade(branch_length=0.16165681, name='HsOr325'),
#  Clade(branch_length=0.27878282, name='CfOr399'),
#  Clade(branch_length=0.24252832, name='CfOr400'),
#  Clade(branch_length=0.22293176, name='HsOr323'),
#  Clade(branch_length=0.14694953, name='LhOr313'),
#  Clade(branch_length=0.16196143, name='LhOr324'),
#  Clade(branch_length=0.29263711, name='HsOr341'),
#  Clade(branch_length=0.14858796, name='PbOr299'),
#  Clade(branch_length=0.5083557, name='PbOr294'),
#  Clade(branch_length=0.26256061, name='HsOr340'),
#  Clade(branch_length=0.1936947, name='PbOr298FI'),
#  Clade(branch_length=0.20640577, name='CfOr353'),
#  Clade(branch_length=0.29903022, name='LhOr323'),
#  Clade(branch_length=0.23823736, name='HsOr339'),
#  Clade(branch_length=0.23007943, name='PbOr297'),
#  Clade(branch_length=0.40766834, name='PbOr281NTE'),
#  Clade(branch_length=0.56657463, name='PbOr285FC'),
#  Clade(branch_length=0.06330105, name='HsOr326'),
#  Clade(branch_length=0.28351985, name='HsOr327'),
#  Clade(branch_length=0.07631466, name='HsOr306'),
#  Clade(branch_length=0.21147892, name='LhOr320'),
#  Clade(branch_length=0.36386372, name='HsOr332'),
#  Clade(branch_length=0.03507277, name='PbOr292FIX'),
#  Clade(branch_length=0.03615057, name='PbOr293FIX'),
#  Clade(branch_length=0.4027026, name='HsOr338'),
#  Clade(branch_length=0.44020874, name='PbOr296'),
#  Clade(branch_length=0.02337231, name='AmOr122'),
#  Clade(branch_length=0.03521259, name='AmOr125'),
#  Clade(branch_length=0.05774462, name='AmOr128'),
#  Clade(branch_length=0.08102303, name='AmOr129FIX'),
#  Clade(branch_length=9.4e-07, name='AmOr124CTE'),
#  Clade(branch_length=0.00455511, name='AmOr126'),
#  Clade(branch_length=0.03159466, name='AmOr123'),
#  Clade(branch_length=0.03672631, name='AmOr127'),
#  Clade(branch_length=0.17597214, name='AmOr130'),
#  Clade(branch_length=0.04390656, name='AmOr137CTE'),
#  Clade(branch_length=0.02787648, name='AmOr138NTE'),
#  Clade(branch_length=0.18654289, name='AmOr136'),
#  Clade(branch_length=0.1153724, name='AmOr135'),
#  Clade(branch_length=0.13046976, name='AmOr132'),
#  Clade(branch_length=0.12662288, name='AmOr131'),
#  Clade(branch_length=0.05247706, name='AmOr133CTE'),
#  Clade(branch_length=0.03967106, name='AmOr134'),
#  Clade(branch_length=0.43407134, name='CfOr394'),
#  Clade(branch_length=0.4096108, name='HsOr310'),
#  Clade(branch_length=0.29738741, name='HsOr307'),
#  Clade(branch_length=0.32276723, name='PbOr283FIX'),
#  Clade(branch_length=0.25540756, name='HsOr309'),
#  Clade(branch_length=0.0782358, name='HsOr328'),
#  Clade(branch_length=0.38512944, name='HsOr331'),
#  Clade(branch_length=0.3840763, name='LhOr318'),
#  Clade(branch_length=0.2923278, name='LhOr319'),
#  Clade(branch_length=0.10283238, name='HsOr308'),
#  Clade(branch_length=0.11503972, name='HsOr329'),
#  Clade(branch_length=0.15542415, name='PbOr286NTE'),
#  Clade(branch_length=0.29760045, name='PbOr287FIX'),
#  Clade(branch_length=0.01622902, name='PbOr288FC'),
#  Clade(branch_length=0.02565177, name='PbOr290FC'),
#  Clade(branch_length=0.16716354, name='CfOr393'),
#  Clade(branch_length=0.16199169, name='CfOr349'),
#  Clade(branch_length=0.14574077, name='CfOr350'),
#  Clade(branch_length=0.14097733, name='CfOr347'),
#  Clade(branch_length=0.18478691, name='LhOr354'),
#  Clade(branch_length=0.25726032, name='LhOr352FN'),
#  Clade(branch_length=0.15415937, name='HsOr335'),
#  Clade(branch_length=0.13466786, name='HsOr336'),
#  Clade(branch_length=0.19538033, name='HsOr337'),
#  Clade(branch_length=0.2518614, name='LhOr322'),
#  Clade(branch_length=0.23122614, name='PbOr295'),
#  Clade(branch_length=0.12406703, name='CfOr352'),
#  Clade(branch_length=0.12949256, name='CfOr337'),
#  Clade(branch_length=0.10011573, name='CfOr339'),
#  Clade(branch_length=0.08207125, name='CfOr340'),
#  Clade(branch_length=0.33644327, name='HsOr277'),
#  Clade(branch_length=0.19450677, name='HsOr273'),
#  Clade(branch_length=0.05784636, name='HsOr275'),
#  Clade(branch_length=0.04578778, name='HsOr274'),
#  Clade(branch_length=0.04416022, name='HsOr276'),
#  Clade(branch_length=0.17206684, name='PbOr393'),
#  Clade(branch_length=0.16053283, name='PbOr394'),
#  Clade(branch_length=0.09311455, name='LhOr266FIX'),
#  Clade(branch_length=0.11082417, name='LhOr267'),
#  Clade(branch_length=0.31779162, name='LhOr264'),
#  Clade(branch_length=0.04685561, name='LhOr268'),
#  Clade(branch_length=0.06659943, name='LhOr269'),
#  Clade(branch_length=0.16938518, name='LhOr273'),
#  Clade(branch_length=0.18682158, name='LhOr270JC'),
#  Clade(branch_length=0.25263726, name='LhOr271'),
#  Clade(branch_length=0.15146279, name='LhOr272'),
#  Clade(branch_length=0.06737978, name='LhOr280'),
#  Clade(branch_length=0.07725658, name='PbOr390INT'),
#  Clade(branch_length=0.18133658, name='PbOr391'),
#  Clade(branch_length=0.20488874, name='PbOr395FIX'),
#  Clade(branch_length=0.06065324, name='LhOr275'),
#  Clade(branch_length=0.04920313, name='LhOr276FIX'),
#  Clade(branch_length=0.18640178, name='LhOr274FIX'),
#  Clade(branch_length=0.17054696, name='LhOr277'),
#  Clade(branch_length=0.09834293, name='LhOr278'),
#  Clade(branch_length=0.13330327, name='LhOr279'),
#  Clade(branch_length=0.25315077, name='HsOr280'),
#  Clade(branch_length=0.22143593, name='HsOr278'),
#  Clade(branch_length=0.28952997, name='HsOr279'),
#  Clade(branch_length=0.38802197, name='CfOr306'),
#  Clade(branch_length=0.18544683, name='PbOr333'),
#  Clade(branch_length=0.18903164, name='PbOr332FI'),
#  Clade(branch_length=0.17589589, name='PbOr329'),
#  Clade(branch_length=0.09291228, name='PbOr331'),
#  Clade(branch_length=0.20962846, name='PbOr328NTE'),
#  Clade(branch_length=0.14232282, name='PbOr330FIX'),
#  Clade(branch_length=0.23695937, name='PbOr334FIX'),
#  Clade(branch_length=0.03422506, name='CfOr308'),
#  Clade(branch_length=0.06413569, name='CfOr329'),
#  Clade(branch_length=0.27318796, name='PbOr335INT'),
#  Clade(branch_length=0.18886579, name='LhOr292'),
#  Clade(branch_length=0.05714073, name='LhOr291'),
#  Clade(branch_length=0.03758292, name='LhOr290FIX'),
#  Clade(branch_length=0.03913205, name='LhOr289FIX'),
#  Clade(branch_length=0.27192137, name='LhOr288FIX'),
#  Clade(branch_length=0.33017568, name='LhOr293'),
#  Clade(branch_length=0.21604117, name='LhOr284'),
#  Clade(branch_length=0.1449874, name='LhOr281'),
#  Clade(branch_length=0.06273673, name='LhOr282'),
#  Clade(branch_length=0.09511615, name='LhOr283NTE'),
#  Clade(branch_length=0.16013601, name='CfOr334'),
#  Clade(branch_length=0.18664422, name='CfOr304'),
#  Clade(branch_length=0.09384022, name='CfOr335'),
#  Clade(branch_length=0.08061022, name='CfOr333'),
#  Clade(branch_length=0.05768105, name='CfOr336'),
#  Clade(branch_length=0.05872286, name='CfOr332'),
#  Clade(branch_length=0.07943009, name='LhOr286'),
#  Clade(branch_length=0.20144847, name='LhOr285'),
#  Clade(branch_length=0.23246226, name='PbOr327'),
#  Clade(branch_length=0.15918748, name='PbOr325FIX'),
#  Clade(branch_length=0.25975038, name='PbOr326'),
#  Clade(branch_length=0.1755671, name='CfOr325'),
#  Clade(branch_length=0.20114792, name='CfOr368'),
#  Clade(branch_length=0.23795398, name='CfOr326'),
#  Clade(branch_length=0.0423424, name='CfOr318'),
#  Clade(branch_length=0.06840335, name='CfOr322'),
#  Clade(branch_length=0.16799909, name='CfOr331'),
#  Clade(branch_length=0.34337677, name='CfOr323'),
#  Clade(branch_length=0.17890299, name='CfOr367'),
#  Clade(branch_length=0.31388564, name='HsOr286'),
#  Clade(branch_length=0.05695346, name='HsOr283'),
#  Clade(branch_length=0.08631242, name='HsOr281'),
#  Clade(branch_length=0.13258524, name='HsOr284'),
#  Clade(branch_length=0.11269745, name='HsOr285'),
#  Clade(branch_length=0.23560104, name='HsOr282'),
#  Clade(branch_length=0.30864493, name='HsOr288'),
#  Clade(branch_length=0.3307337, name='HsOr287'),
#  Clade(branch_length=0.22640973, name='CfOr328'),
#  Clade(branch_length=0.21515526, name='PbOr337'),
#  Clade(branch_length=0.18444485, name='LhOr300'),
#  Clade(branch_length=0.22383777, name='LhOr297'),
#  Clade(branch_length=0.18835929, name='LhOr296'),
#  Clade(branch_length=0.13665696, name='LhOr298'),
#  Clade(branch_length=0.05548452, name='HsOr293'),
#  Clade(branch_length=0.02536576, name='HsOr290'),
#  Clade(branch_length=0.02950366, name='HsOr291'),
#  Clade(branch_length=0.08393505, name='HsOr292'),
#  Clade(branch_length=0.04897971, name='HsOr289'),
#  Clade(branch_length=0.06205905, name='LhOr309'),
#  Clade(branch_length=0.08120195, name='LhOr308'),
#  Clade(branch_length=0.04620109, name='LhOr305'),
#  Clade(branch_length=0.04155629, name='LhOr306'),
#  Clade(branch_length=0.06183358, name='LhOr307'),
#  Clade(branch_length=0.09953633, name='PbOr341FIX'),
#  Clade(branch_length=0.14462175, name='PbOr342'),
#  Clade(branch_length=0.15235729, name='PbOr344'),
#  Clade(branch_length=0.09592911, name='PbOr347'),
#  Clade(branch_length=0.16807205, name='PbOr346'),
#  Clade(branch_length=0.31398278, name='PbOr340FIX'),
#  Clade(branch_length=0.08703655, name='CfOr371'),
#  Clade(branch_length=0.04421518, name='CfOr369'),
#  Clade(branch_length=0.02653348, name='CfOr370'),
#  Clade(branch_length=0.12954315, name='CfOr303'),
#  Clade(branch_length=0.14094258, name='CfOr374'),
#  Clade(branch_length=0.17423009, name='CfOr375'),
#  Clade(branch_length=0.19913298, name='PbOr339'),
#  Clade(branch_length=0.15700298, name='PbOr338'),
#  Clade(branch_length=0.10501346, name='CfOr327'),
#  Clade(branch_length=0.1030408, name='CfOr301'),
#  Clade(branch_length=0.20280311, name='CfOr302'),
#  Clade(branch_length=0.11804339, name='LhOr304'),
#  Clade(branch_length=0.06186618, name='LhOr301'),
#  Clade(branch_length=0.05258203, name='LhOr302'),
#  Clade(branch_length=0.11743672, name='LhOr303FIX'),
#  Clade(branch_length=0.32577082, name='HsOr296'),
#  Clade(branch_length=0.37367172, name='HsOr302'),
#  Clade(branch_length=0.34972895, name='LhOr312'),
#  Clade(branch_length=0.23587487, name='HsOr294'),
#  Clade(branch_length=0.17787645, name='HsOr295'),
#  Clade(branch_length=0.22039101, name='HsOr248'),
#  Clade(branch_length=0.2156252, name='HsOr247'),
#  Clade(branch_length=0.07540189, name='HsOr250'),
#  Clade(branch_length=0.08844742, name='HsOr249'),
#  Clade(branch_length=0.05782149, name='HsOr251'),
#  Clade(branch_length=0.30881692, name='HsOr252'),
#  Clade(branch_length=0.18256844, name='HsOr253'),
#  Clade(branch_length=0.40344164, name='HsOr297'),
#  Clade(branch_length=0.39349327, name='HsOr298'),
#  Clade(branch_length=0.40114402, name='HsOr299'),
#  Clade(branch_length=0.01924695, name='HsOr301'),
#  Clade(branch_length=0.03588068, name='HsOr300'),
#  Clade(branch_length=0.23526543, name='HsOr266'),
#  Clade(branch_length=0.2774484, name='HsOr265'),
#  Clade(branch_length=0.27452734, name='HsOr264'),
#  Clade(branch_length=0.01059722, name='HsOr267'),
#  Clade(branch_length=0.00998773, name='HsOr269'),
#  Clade(branch_length=0.05391328, name='HsOr268'),
#  Clade(branch_length=0.04390684, name='HsOr271'),
#  Clade(branch_length=0.13639224, name='PbOr365FIX'),
#  Clade(branch_length=0.19764336, name='LhOr310'),
#  Clade(branch_length=0.15675619, name='LhOr311'),
#  Clade(branch_length=0.19661299, name='PbOr367FIX'),
#  Clade(branch_length=0.19949691, name='CfOr385'),
#  Clade(branch_length=0.03488424, name='CfOr310'),
#  Clade(branch_length=0.0243476, name='CfOr386'),
#  Clade(branch_length=0.13723129, name='CfOr311'),
#  Clade(branch_length=0.09921613, name='CfOr314'),
#  Clade(branch_length=0.09589371, name='CfOr317'),
#  Clade(branch_length=0.0493574, name='CfOr315'),
#  Clade(branch_length=0.04663916, name='CfOr316'),
#  Clade(branch_length=0.21132327, name='PbOr399'),
#  Clade(branch_length=0.13219349, name='PbOr396FIX'),
#  Clade(branch_length=0.02296196, name='PbOr397FI'),
#  Clade(branch_length=0.04429839, name='PbOr398FIX'),
#  Clade(branch_length=0.2789594, name='CfOr313'),
#  Clade(branch_length=0.12811791, name='CfOr293'),
#  Clade(branch_length=0.2667808, name='CfOr312'),
#  Clade(branch_length=0.12214146, name='CfOr278'),
#  Clade(branch_length=0.04942089, name='CfOr294'),
#  Clade(branch_length=0.08454168, name='CfOr295'),
#  Clade(branch_length=0.25707776, name='CfOr376'),
#  Clade(branch_length=0.20625549, name='CfOr382'),
#  Clade(branch_length=0.17319118, name='CfOr383'),
#  Clade(branch_length=0.13633131, name='CfOr377'),
#  Clade(branch_length=0.16962441, name='CfOr380'),
#  Clade(branch_length=0.12214396, name='CfOr381'),
#  Clade(branch_length=0.05791121, name='CfOr378'),
#  Clade(branch_length=0.07916696, name='CfOr379'),
#  Clade(branch_length=0.06004719, name='PbOr357FIX'),
#  Clade(branch_length=0.02975445, name='PbOr353'),
#  Clade(branch_length=0.02532527, name='PbOr355'),
#  Clade(branch_length=0.11233421, name='PbOr356INT'),
#  Clade(branch_length=0.00533756, name='PbOr350FIX'),
#  Clade(branch_length=0.01672325, name='PbOr351FIX'),
#  Clade(branch_length=0.08922947, name='PbOr349INT'),
#  Clade(branch_length=0.16804234, name='PbOr352INT'),
#  Clade(branch_length=0.03823162, name='PbOr363FIX'),
#  Clade(branch_length=0.03728109, name='PbOr364'),
#  Clade(branch_length=0.00622094, name='PbOr362'),
#  Clade(branch_length=9.4e-07, name='PbOr360FC'),
#  Clade(branch_length=0.03237204, name='PbOr361CTE'),
#  Clade(branch_length=0.02616292, name='PbOr358'),
#  Clade(branch_length=9.4e-07, name='PbOr359FN'),
#  Clade(branch_length=0.09449906, name='NvOr296'),
#  Clade(branch_length=0.16280903, name='NvOr297PSE'),
#  Clade(branch_length=0.18652132, name='AmOr161'),
#  Clade(branch_length=0.15244188, name='HsOr177'),
#  Clade(branch_length=0.21417071, name='PbOr145'),
#  Clade(branch_length=0.04659627, name='CfOr190'),
#  Clade(branch_length=0.07792596, name='PbOr154'),
#  Clade(branch_length=0.06036739, name='HsOr189'),
#  Clade(branch_length=0.1010795, name='LhOr213'),
#  Clade(branch_length=0.100089, name='PbOr153'),
#  Clade(branch_length=0.14270529, name='LhOr212'),
#  Clade(branch_length=0.19392534, name='CfOr189'),
#  Clade(branch_length=0.18576387, name='HsOr190'),
#  Clade(branch_length=0.1716015, name='AmOr94'),
#  Clade(branch_length=0.25770202, name='AmOr96'),
#  Clade(branch_length=0.22684483, name='AmOr88'),
#  Clade(branch_length=0.21752262, name='AmOr76'),
#  Clade(branch_length=0.24220522, name='AmOr85'),
#  Clade(branch_length=0.28294206, name='AmOr77CTE'),
#  Clade(branch_length=0.15328901, name='AmOr91'),
#  Clade(branch_length=0.18631865, name='AmOr95'),
#  Clade(branch_length=0.26153824, name='AmOr74FIX'),
#  Clade(branch_length=0.15760878, name='AmOr86'),
#  Clade(branch_length=0.22227385, name='AmOr87'),
#  Clade(branch_length=0.13841041, name='AmOr75'),
#  Clade(branch_length=0.13893752, name='AmOr84'),
#  Clade(branch_length=0.22223205, name='AmOr89'),
#  Clade(branch_length=0.13999042, name='AmOr90'),
#  Clade(branch_length=0.10870916, name='AmOr78'),
#  Clade(branch_length=0.1111098, name='AmOr83FIX'),
#  Clade(branch_length=0.08043566, name='AmOr79'),
#  Clade(branch_length=0.08635797, name='AmOr82'),
#  Clade(branch_length=0.06196898, name='AmOr80'),
#  Clade(branch_length=0.0446695, name='AmOr81'),
#  Clade(branch_length=0.75379916, name='HsOr371'),
#  Clade(branch_length=1.00860128, name='NvOr299'),
#  ...]

# %%
#tree.get_nonterminals()
# Out:
# [Clade(),
#  Clade(branch_length=0.03953197, confidence=39),
#  Clade(branch_length=0.11247075, confidence=78),
#  Clade(branch_length=0.01197314, confidence=65),
#  Clade(branch_length=0.00592873, confidence=45),
#  Clade(branch_length=1.31753257, confidence=100),
#  Clade(branch_length=1.32861791, confidence=100),
#  Clade(branch_length=0.23903436, confidence=30),
#  Clade(branch_length=0.07097824, confidence=67),
#  Clade(branch_length=0.06808209, confidence=16),
#  Clade(branch_length=0.05587721, confidence=22),
#  Clade(branch_length=0.18505444, confidence=95),
#  Clade(branch_length=0.28529852, confidence=99),
#  Clade(branch_length=0.05161639, confidence=68),
#  Clade(branch_length=0.02359982, confidence=14),
#  Clade(branch_length=0.03908886, confidence=29),
#  Clade(branch_length=0.03324154, confidence=3),
#  Clade(branch_length=0.04948974, confidence=9),
#  Clade(branch_length=0.10280977, confidence=85),
#  Clade(branch_length=0.04753704, confidence=72),
#  Clade(branch_length=0.02680967, confidence=44),
#  Clade(branch_length=0.01464919, confidence=27),
#  Clade(branch_length=0.08565984, confidence=99),
#  Clade(branch_length=0.04149271, confidence=65),
#  Clade(branch_length=0.18648547, confidence=100),
#  Clade(branch_length=0.09840275, confidence=100),
#  Clade(branch_length=0.02619766, confidence=19),
#  Clade(branch_length=0.12539207, confidence=98),
#  Clade(branch_length=0.03051348, confidence=67),
#  Clade(branch_length=0.14773759, confidence=99),
#  Clade(branch_length=0.02797942, confidence=14),
#  Clade(branch_length=0.03714958, confidence=19),
#  Clade(branch_length=0.07816368, confidence=70),
#  Clade(branch_length=0.03505946, confidence=66),
#  Clade(branch_length=0.05900509, confidence=72),
#  Clade(branch_length=0.07928026, confidence=97),
#  Clade(branch_length=0.05068175, confidence=20),
#  Clade(branch_length=0.52378082, confidence=100),
#  Clade(branch_length=0.11292153, confidence=99),
#  Clade(branch_length=0.04360723, confidence=41),
#  Clade(branch_length=0.07948324, confidence=66),
#  Clade(branch_length=0.08466176, confidence=88),
#  Clade(branch_length=0.09081047, confidence=80),
#  Clade(branch_length=0.09060287, confidence=93),
#  Clade(branch_length=0.060088, confidence=79),
#  Clade(branch_length=0.14045123, confidence=100),
#  Clade(branch_length=0.0220431, confidence=41),
#  Clade(branch_length=0.02093926, confidence=43),
#  Clade(branch_length=0.05159258, confidence=90),
#  Clade(branch_length=0.01506369, confidence=42),
#  Clade(branch_length=0.04945072, confidence=63),
#  Clade(branch_length=0.0164167, confidence=44),
#  Clade(branch_length=0.0737878, confidence=95),
#  Clade(branch_length=0.18986203, confidence=49),
#  Clade(branch_length=1.09742381, confidence=100),
#  Clade(branch_length=0.04576506, confidence=45),
#  Clade(branch_length=0.02751464, confidence=20),
#  Clade(branch_length=0.04575751, confidence=33),
#  Clade(branch_length=0.11510032, confidence=21),
#  Clade(branch_length=0.17346804, confidence=71),
#  Clade(branch_length=0.64397668, confidence=100),
#  Clade(branch_length=0.3207303, confidence=99),
#  Clade(branch_length=0.04672433, confidence=45),
#  Clade(branch_length=0.01595681, confidence=49),
#  Clade(branch_length=0.18343008, confidence=91),
#  Clade(branch_length=0.46094054, confidence=91),
#  Clade(branch_length=0.13090843, confidence=85),
#  Clade(branch_length=0.12227046, confidence=85),
#  Clade(branch_length=0.07024095, confidence=59),
#  Clade(branch_length=0.08729257, confidence=76),
#  Clade(branch_length=0.68127545, confidence=100),
#  Clade(branch_length=0.03273704, confidence=49),
#  Clade(branch_length=0.18621093, confidence=97),
#  Clade(branch_length=0.12288008, confidence=99),
#  Clade(branch_length=0.13051703, confidence=96),
#  Clade(branch_length=0.19524037, confidence=100),
#  Clade(branch_length=0.14165221, confidence=99),
#  Clade(branch_length=0.10901562, confidence=100),
#  Clade(branch_length=0.04728752, confidence=54),
#  Clade(branch_length=0.0969341, confidence=99),
#  Clade(branch_length=0.16084558, confidence=100),
#  Clade(branch_length=0.06034513, confidence=90),
#  Clade(branch_length=0.03492541, confidence=42),
#  Clade(branch_length=0.01863775, confidence=33),
#  Clade(branch_length=0.17083312, confidence=100),
#  Clade(branch_length=0.10363657, confidence=100),
#  Clade(branch_length=0.04990227, confidence=75),
#  Clade(branch_length=0.04409714, confidence=81),
#  Clade(branch_length=0.08346595, confidence=99),
#  Clade(branch_length=0.00801731, confidence=41),
#  Clade(branch_length=0.14698587, confidence=96),
#  Clade(branch_length=0.0766379, confidence=39),
#  Clade(branch_length=0.22323916, confidence=99),
#  Clade(branch_length=0.22388, confidence=100),
#  Clade(branch_length=0.22679471, confidence=96),
#  Clade(branch_length=0.12864757, confidence=64),
#  Clade(branch_length=0.1309252, confidence=78),
#  Clade(branch_length=0.34444756, confidence=100),
#  Clade(branch_length=0.10790688, confidence=85),
#  Clade(branch_length=0.17465107, confidence=99),
#  Clade(branch_length=0.45952892, confidence=100),
#  Clade(branch_length=0.08664502, confidence=87),
#  Clade(branch_length=0.20686663, confidence=100),
#  Clade(branch_length=0.12667737, confidence=96),
#  Clade(branch_length=0.32802177, confidence=100),
#  Clade(branch_length=0.17083978, confidence=100),
#  Clade(branch_length=0.07973241, confidence=89),
#  Clade(branch_length=0.14868166, confidence=100),
#  Clade(branch_length=0.03443719, confidence=13),
#  Clade(branch_length=0.05054003, confidence=20),
#  Clade(branch_length=0.1224823, confidence=59),
#  Clade(branch_length=0.09110314, confidence=29),
#  Clade(branch_length=0.09212325, confidence=29),
#  Clade(branch_length=0.11648447, confidence=48),
#  Clade(branch_length=0.0764565, confidence=15),
#  Clade(branch_length=0.08136336, confidence=43),
#  Clade(branch_length=0.40298878, confidence=100),
#  Clade(branch_length=0.0727487, confidence=50),
#  Clade(branch_length=0.43019867, confidence=100),
#  Clade(branch_length=0.06249488, confidence=58),
#  Clade(branch_length=0.09121219, confidence=67),
#  Clade(branch_length=0.34923902, confidence=100),
#  Clade(branch_length=0.13842438, confidence=95),
#  Clade(branch_length=0.1069049, confidence=97),
#  Clade(branch_length=0.00833696, confidence=43),
#  Clade(branch_length=0.02797764, confidence=93),
#  Clade(branch_length=0.13170085, confidence=100),
#  Clade(branch_length=0.02675711, confidence=72),
#  Clade(branch_length=0.16078167, confidence=99),
#  Clade(branch_length=0.02926162, confidence=78),
#  Clade(branch_length=0.09263464, confidence=100),
#  Clade(branch_length=0.0749458, confidence=100),
#  Clade(branch_length=0.05385057, confidence=98),
#  Clade(branch_length=0.00921462, confidence=51),
#  Clade(branch_length=0.02225392, confidence=79),
#  Clade(branch_length=0.04580196, confidence=6),
#  Clade(branch_length=0.12540698, confidence=53),
#  Clade(branch_length=0.07165071, confidence=36),
#  Clade(branch_length=0.33016701, confidence=100),
#  Clade(branch_length=0.13146838, confidence=100),
#  Clade(branch_length=0.04242108, confidence=88),
#  Clade(branch_length=0.07562142, confidence=95),
#  Clade(branch_length=0.03239386, confidence=38),
#  Clade(branch_length=0.04321051, confidence=54),
#  Clade(branch_length=0.11052219, confidence=100),
#  Clade(branch_length=0.01320439, confidence=39),
#  Clade(branch_length=0.04383099, confidence=100),
#  Clade(branch_length=0.13580592, confidence=96),
#  Clade(branch_length=0.11884573, confidence=100),
#  Clade(branch_length=0.01323692, confidence=85),
#  Clade(branch_length=0.08842758, confidence=100),
#  Clade(branch_length=0.05287691, confidence=63),
#  Clade(branch_length=0.04092415, confidence=72),
#  Clade(branch_length=0.03811085, confidence=33),
#  Clade(branch_length=0.03010607, confidence=50),
#  Clade(branch_length=0.02280144, confidence=39),
#  Clade(branch_length=0.10720818, confidence=100),
#  Clade(branch_length=0.01926036, confidence=90),
#  Clade(branch_length=0.01247424, confidence=58),
#  Clade(branch_length=0.00457854, confidence=76),
#  Clade(branch_length=0.01248287, confidence=66),
#  Clade(branch_length=0.05562833, confidence=62),
#  Clade(branch_length=0.02173702, confidence=41),
#  Clade(branch_length=0.01763062, confidence=64),
#  Clade(branch_length=0.05894445, confidence=94),
#  Clade(branch_length=0.01745044, confidence=42),
#  Clade(branch_length=0.03064581, confidence=98),
#  Clade(branch_length=0.01894004, confidence=33),
#  Clade(branch_length=0.01736903, confidence=26),
#  Clade(branch_length=0.13400607, confidence=100),
#  Clade(branch_length=0.03605511, confidence=39),
#  Clade(branch_length=0.02407323, confidence=33),
#  Clade(branch_length=0.0267141, confidence=31),
#  Clade(branch_length=0.25180071, confidence=100),
#  Clade(branch_length=0.1870638, confidence=99),
#  Clade(branch_length=0.0274778, confidence=25),
#  Clade(branch_length=0.0920483, confidence=74),
#  Clade(branch_length=0.0637464, confidence=55),
#  Clade(branch_length=0.14970272, confidence=89),
#  Clade(branch_length=0.03342948, confidence=83),
#  Clade(branch_length=0.07675889, confidence=97),
#  Clade(branch_length=0.08354084, confidence=100),
#  Clade(branch_length=0.10560789, confidence=100),
#  Clade(branch_length=0.10205831, confidence=98),
#  Clade(branch_length=0.11421793, confidence=99),
#  Clade(branch_length=0.03557038, confidence=80),
#  Clade(branch_length=0.05137524, confidence=84),
#  Clade(branch_length=0.10631468, confidence=100),
#  Clade(branch_length=0.022472, confidence=71),
#  Clade(branch_length=0.0331809, confidence=72),
#  Clade(branch_length=0.1204726, confidence=100),
#  Clade(branch_length=0.05544133, confidence=95),
#  Clade(branch_length=0.08112092, confidence=98),
#  Clade(branch_length=0.01283233, confidence=54),
#  Clade(branch_length=0.09322828, confidence=100),
#  Clade(branch_length=0.0221003, confidence=71),
#  Clade(branch_length=0.11534654, confidence=100),
#  Clade(branch_length=0.05216551, confidence=94),
#  Clade(branch_length=0.07389674, confidence=99),
#  Clade(branch_length=0.01758098, confidence=45),
#  Clade(branch_length=0.07042332, confidence=97),
#  Clade(branch_length=0.02928508, confidence=88),
#  Clade(branch_length=0.03652292, confidence=67),
#  Clade(branch_length=0.1523758, confidence=100),
#  Clade(branch_length=0.031734, confidence=74),
#  Clade(branch_length=0.04321677, confidence=99),
#  Clade(branch_length=0.07087576, confidence=100),
#  Clade(branch_length=0.02663236, confidence=50),
#  Clade(branch_length=0.07260542, confidence=95),
#  Clade(branch_length=0.1495182, confidence=100),
#  Clade(branch_length=0.05534, confidence=85),
#  Clade(branch_length=0.07835815, confidence=90),
#  Clade(branch_length=0.08611233, confidence=100),
#  Clade(branch_length=0.11005305, confidence=98),
#  Clade(branch_length=0.06785262, confidence=97),
#  Clade(branch_length=0.17115804, confidence=100),
#  Clade(branch_length=0.03598975, confidence=41),
#  Clade(branch_length=0.13467843, confidence=100),
#  Clade(branch_length=0.09845864, confidence=100),
#  Clade(branch_length=0.05769968, confidence=93),
#  Clade(branch_length=0.07264137, confidence=98),
#  Clade(branch_length=0.04804651, confidence=95),
#  Clade(branch_length=0.06847208, confidence=100),
#  Clade(branch_length=0.0830211, confidence=100),
#  Clade(branch_length=0.06567383, confidence=87),
#  Clade(branch_length=0.17995564, confidence=100),
#  Clade(branch_length=0.07374015, confidence=94),
#  Clade(branch_length=0.17140367, confidence=100),
#  Clade(branch_length=0.23551772, confidence=100),
#  Clade(branch_length=0.03383223, confidence=73),
#  Clade(branch_length=0.09944409, confidence=100),
#  Clade(branch_length=0.09432492, confidence=98),
#  Clade(branch_length=0.01792766, confidence=61),
#  Clade(branch_length=0.16853153, confidence=100),
#  Clade(branch_length=0.14017842, confidence=100),
#  Clade(branch_length=0.04943799, confidence=79),
#  Clade(branch_length=0.03185671, confidence=59),
#  Clade(branch_length=0.03774205, confidence=88),
#  Clade(branch_length=0.05559434, confidence=100),
#  Clade(branch_length=0.11740492, confidence=36),
#  Clade(branch_length=0.16395442, confidence=31),
#  Clade(branch_length=0.22174526, confidence=56),
#  Clade(branch_length=0.79803314, confidence=100),
#  Clade(branch_length=0.21997249, confidence=90),
#  Clade(branch_length=0.21450288, confidence=90),
#  Clade(branch_length=0.0840962, confidence=62),
#  Clade(branch_length=0.35193125, confidence=100),
#  Clade(branch_length=0.11961534, confidence=95),
#  Clade(branch_length=0.03871907, confidence=67),
#  Clade(branch_length=0.0834742, confidence=79),
#  Clade(branch_length=0.08808519, confidence=93),
#  Clade(branch_length=0.25984925, confidence=100),
#  Clade(branch_length=0.13741183, confidence=100),
#  Clade(branch_length=0.32895992, confidence=97),
#  Clade(branch_length=0.08166362, confidence=85),
#  Clade(branch_length=0.32978873, confidence=99),
#  Clade(branch_length=0.11468327, confidence=96),
#  Clade(branch_length=0.15390916, confidence=100),
#  Clade(branch_length=0.08279114, confidence=75),
#  Clade(branch_length=0.06128717, confidence=95),
#  Clade(branch_length=0.01251776, confidence=54),
#  Clade(branch_length=0.14720146, confidence=99),
#  Clade(branch_length=0.1871949, confidence=69),
#  Clade(branch_length=0.32747043, confidence=100),
#  Clade(branch_length=0.29924383, confidence=100),
#  Clade(branch_length=0.08992001, confidence=58),
#  Clade(branch_length=0.03617255, confidence=47),
#  Clade(branch_length=0.44780995, confidence=100),
#  Clade(branch_length=0.05183523, confidence=71),
#  Clade(branch_length=0.06888642, confidence=74),
#  Clade(branch_length=0.0557728, confidence=57),
#  Clade(branch_length=0.08484564, confidence=99),
#  Clade(branch_length=0.07626673, confidence=100),
#  Clade(branch_length=1.0666154, confidence=100),
#  Clade(branch_length=0.16746095, confidence=61),
#  Clade(branch_length=0.0822485, confidence=92),
#  Clade(branch_length=0.23717936, confidence=79),
#  Clade(branch_length=0.25535676, confidence=100),
#  Clade(branch_length=0.07629802, confidence=77),
#  Clade(branch_length=0.20280828, confidence=100),
#  Clade(branch_length=0.12827122, confidence=100),
#  Clade(branch_length=0.04209431, confidence=47),
#  Clade(branch_length=0.14155054, confidence=93),
#  Clade(branch_length=0.06616187, confidence=86),
#  Clade(branch_length=0.09420943, confidence=92),
#  Clade(branch_length=0.15263806, confidence=100),
#  Clade(branch_length=0.09111772, confidence=74),
#  Clade(branch_length=0.11011271, confidence=95),
#  Clade(branch_length=0.09091505, confidence=98),
#  Clade(branch_length=0.19055218, confidence=100),
#  Clade(branch_length=0.06311815, confidence=100),
#  Clade(branch_length=0.13963201, confidence=67),
#  Clade(branch_length=1.05452596, confidence=100),
#  Clade(branch_length=0.35257122, confidence=100),
#  Clade(branch_length=0.5184473, confidence=100),
#  Clade(branch_length=0.33155856, confidence=100),
#  Clade(branch_length=0.23951985, confidence=97),
#  Clade(branch_length=0.26366876, confidence=100),
#  Clade(branch_length=0.14878236, confidence=82),
#  Clade(branch_length=0.17068023, confidence=97),
#  Clade(branch_length=0.10914394, confidence=76),
#  Clade(branch_length=0.20759541, confidence=98),
#  Clade(branch_length=0.07505044, confidence=30),
#  Clade(branch_length=0.04550179, confidence=27),
#  Clade(branch_length=0.06335041, confidence=41),
#  Clade(branch_length=0.65736346, confidence=100),
#  Clade(branch_length=0.15552444, confidence=76),
#  Clade(branch_length=0.17079634, confidence=70),
#  Clade(branch_length=0.11511519, confidence=95),
#  Clade(branch_length=0.16189583, confidence=96),
#  Clade(branch_length=0.07406268, confidence=32),
#  Clade(branch_length=0.52351281, confidence=100),
#  Clade(branch_length=0.08638264, confidence=98),
#  Clade(branch_length=0.58689188, confidence=100),
#  Clade(branch_length=0.08553291, confidence=100),
#  Clade(branch_length=0.05312327, confidence=27),
#  Clade(branch_length=0.07073966, confidence=54),
#  Clade(branch_length=0.17851517, confidence=98),
#  Clade(branch_length=0.10656758, confidence=100),
#  Clade(branch_length=0.2300485, confidence=100),
#  Clade(branch_length=0.09954175, confidence=98),
#  Clade(branch_length=0.04908372, confidence=70),
#  Clade(branch_length=0.35692492, confidence=96),
#  Clade(branch_length=0.14181726, confidence=91),
#  Clade(branch_length=0.18995066, confidence=100),
#  Clade(branch_length=0.17480306, confidence=100),
#  Clade(branch_length=0.04623041, confidence=60),
#  Clade(branch_length=0.20102782, confidence=100),
#  Clade(branch_length=0.05684231, confidence=50),
#  Clade(branch_length=0.24956475, confidence=100),
#  Clade(branch_length=0.33328399, confidence=100),
#  Clade(branch_length=0.32426976, confidence=100),
#  Clade(branch_length=0.14484195, confidence=100),
#  Clade(branch_length=0.21730534, confidence=100),
#  Clade(branch_length=0.03798515, confidence=36),
#  Clade(branch_length=0.07097683, confidence=62),
#  Clade(branch_length=0.203287, confidence=100),
#  Clade(branch_length=0.04921216, confidence=64),
#  Clade(branch_length=0.03062669, confidence=58),
#  Clade(branch_length=0.02637725, confidence=51),
#  Clade(branch_length=0.34905625, confidence=100),
#  Clade(branch_length=0.05540902, confidence=88),
#  Clade(branch_length=0.02126061, confidence=62),
#  Clade(branch_length=0.06044504, confidence=62),
#  Clade(branch_length=0.03186582, confidence=55),
#  Clade(branch_length=0.06657858, confidence=72),
#  Clade(branch_length=0.16766708, confidence=96),
#  Clade(branch_length=0.42871847, confidence=100),
#  Clade(branch_length=0.01718714, confidence=37),
#  Clade(branch_length=0.02629348, confidence=18),
#  Clade(branch_length=0.07712651, confidence=43),
#  Clade(branch_length=0.10290893, confidence=76),
#  Clade(branch_length=0.16253733, confidence=100),
#  Clade(branch_length=0.03531574, confidence=50),
#  Clade(branch_length=0.13795018, confidence=100),
#  Clade(branch_length=0.05801309, confidence=53),
#  Clade(branch_length=0.04544775, confidence=54),
#  Clade(branch_length=0.10779621, confidence=86),
#  Clade(branch_length=0.31125027, confidence=100),
#  Clade(branch_length=0.06953848, confidence=79),
#  Clade(branch_length=0.20580777, confidence=100),
#  Clade(branch_length=0.31037751, confidence=100),
#  Clade(branch_length=0.06604921, confidence=91),
#  Clade(branch_length=0.05790491, confidence=53),
#  Clade(branch_length=0.17648936, confidence=100),
#  Clade(branch_length=0.10336232, confidence=98),
#  Clade(branch_length=0.19838811, confidence=100),
#  Clade(branch_length=0.04774229, confidence=93),
#  Clade(branch_length=0.20620351, confidence=100),
#  Clade(branch_length=0.07233235, confidence=69),
#  Clade(branch_length=0.17145219, confidence=100),
#  Clade(branch_length=0.12740607, confidence=97),
#  Clade(branch_length=0.05534344, confidence=42),
#  Clade(branch_length=0.6868287, confidence=100),
#  Clade(branch_length=0.0698185, confidence=15),
#  Clade(branch_length=0.21064179, confidence=53),
#  Clade(branch_length=0.32256914, confidence=99),
#  Clade(branch_length=0.4155422, confidence=100),
#  Clade(branch_length=0.16125799, confidence=98),
#  Clade(branch_length=0.03680071, confidence=77),
#  Clade(branch_length=0.05128963, confidence=38),
#  Clade(branch_length=0.0743845, confidence=67),
#  Clade(branch_length=0.34690935, confidence=100),
#  Clade(branch_length=0.06790243, confidence=60),
#  Clade(branch_length=0.02495097, confidence=33),
#  Clade(branch_length=0.09676061, confidence=99),
#  Clade(branch_length=0.05909257, confidence=99),
#  Clade(branch_length=0.03169365, confidence=41),
#  Clade(branch_length=0.23138975, confidence=100),
#  Clade(branch_length=0.06330485, confidence=86),
#  Clade(branch_length=0.09915929, confidence=40),
#  Clade(branch_length=0.0758646, confidence=34),
#  Clade(branch_length=0.6665274, confidence=100),
#  Clade(branch_length=0.02262177, confidence=58),
#  Clade(branch_length=0.04451057, confidence=89),
#  Clade(branch_length=0.02736624, confidence=52),
#  Clade(branch_length=0.06273014, confidence=52),
#  Clade(branch_length=0.03318706, confidence=59),
#  Clade(branch_length=0.116639, confidence=100),
#  Clade(branch_length=0.02213943, confidence=49),
#  Clade(branch_length=0.13248583, confidence=97),
#  Clade(branch_length=0.0283205, confidence=38),
#  Clade(branch_length=0.28506278, confidence=100),
#  Clade(branch_length=0.13797112, confidence=99),
#  Clade(branch_length=0.05338803, confidence=90),
#  Clade(branch_length=0.0422441, confidence=57),
#  Clade(branch_length=0.15684118, confidence=66),
#  Clade(branch_length=0.49706852, confidence=100),
#  Clade(branch_length=0.03042373, confidence=23),
#  Clade(branch_length=0.56007846, confidence=100),
#  Clade(branch_length=0.07609681, confidence=52),
#  Clade(branch_length=0.06993159, confidence=65),
#  Clade(branch_length=0.06888006, confidence=83),
#  Clade(branch_length=0.0866469, confidence=83),
#  Clade(branch_length=0.09818465, confidence=97),
#  Clade(branch_length=0.07939273, confidence=98),
#  Clade(branch_length=0.01396459, confidence=46),
#  Clade(branch_length=0.09992381, confidence=88),
#  Clade(branch_length=0.03353644, confidence=45),
#  Clade(branch_length=0.05067849, confidence=65),
#  Clade(branch_length=0.04071894, confidence=74),
#  Clade(branch_length=0.0405226, confidence=10),
#  Clade(branch_length=0.07628575, confidence=11),
#  Clade(branch_length=0.09429151, confidence=37),
#  Clade(branch_length=0.35396548, confidence=100),
#  Clade(branch_length=0.12041786, confidence=99),
#  Clade(branch_length=0.13783383, confidence=96),
#  Clade(branch_length=0.29589774, confidence=100),
#  Clade(branch_length=0.06321117, confidence=60),
#  Clade(branch_length=0.486382, confidence=100),
#  Clade(branch_length=0.29510383, confidence=100),
#  Clade(branch_length=0.15062852, confidence=98),
#  Clade(branch_length=0.11785932, confidence=90),
#  Clade(branch_length=0.31674554, confidence=100),
#  Clade(branch_length=0.18752507, confidence=99),
#  Clade(branch_length=0.31259887, confidence=100),
#  Clade(branch_length=0.12341184, confidence=96),
#  Clade(branch_length=0.08321022, confidence=47),
#  Clade(branch_length=0.23216255, confidence=99),
#  Clade(branch_length=0.20922554, confidence=100),
#  Clade(branch_length=0.27505764, confidence=100),
#  Clade(branch_length=0.06940248, confidence=56),
#  Clade(branch_length=0.33010244, confidence=100),
#  Clade(branch_length=0.55244978, confidence=100),
#  Clade(branch_length=0.08856547, confidence=40),
#  Clade(branch_length=0.24879202, confidence=100),
#  Clade(branch_length=0.43261659, confidence=100),
#  Clade(branch_length=0.29500152, confidence=100),
#  Clade(branch_length=0.03865982, confidence=62),
#  Clade(branch_length=0.03235137, confidence=43),
#  Clade(branch_length=0.18088161, confidence=100),
#  Clade(branch_length=0.03455265, confidence=89),
#  Clade(branch_length=0.02910648, confidence=24),
#  Clade(branch_length=0.1256524, confidence=91),
#  Clade(branch_length=0.18675147, confidence=99),
#  Clade(branch_length=0.67033914, confidence=100),
#  Clade(branch_length=0.0850493, confidence=100),
#  Clade(branch_length=0.12779071, confidence=82),
#  Clade(branch_length=0.16075669, confidence=100),
#  Clade(branch_length=0.36858074, confidence=100),
#  Clade(branch_length=0.16393633, confidence=100),
#  Clade(branch_length=0.06384358, confidence=42),
#  Clade(branch_length=0.26620576, confidence=100),
#  Clade(branch_length=0.12283388, confidence=90),
#  Clade(branch_length=0.13062317, confidence=99),
#  Clade(branch_length=0.13918244, confidence=96),
#  Clade(branch_length=0.23742772, confidence=100),
#  Clade(branch_length=0.25325071, confidence=100),
#  Clade(branch_length=0.14767168, confidence=100),
#  Clade(branch_length=0.09352087, confidence=92),
#  Clade(branch_length=0.07771972, confidence=62),
#  Clade(branch_length=0.28488494, confidence=100),
#  Clade(branch_length=0.38808263, confidence=100),
#  Clade(branch_length=0.17631063, confidence=97),
#  Clade(branch_length=0.11913805, confidence=99),
#  Clade(branch_length=0.13222679, confidence=100),
#  Clade(branch_length=0.14478032, confidence=97),
#  Clade(branch_length=0.03504242, confidence=39),
#  Clade(branch_length=0.05840601, confidence=62),
#  Clade(branch_length=0.06067828, confidence=60),
#  Clade(branch_length=0.06385505, confidence=59),
#  Clade(branch_length=0.21725404, confidence=100),
#  Clade(branch_length=0.06299592, confidence=59),
#  Clade(branch_length=0.29880055, confidence=100),
#  Clade(branch_length=0.03519165, confidence=67),
#  Clade(branch_length=0.06222868, confidence=1),
#  Clade(branch_length=0.05309354, confidence=5),
#  Clade(branch_length=0.11809768, confidence=30),
#  Clade(branch_length=0.60038232, confidence=100),
#  Clade(branch_length=0.21919267, confidence=97),
#  Clade(branch_length=0.04835128, confidence=82),
#  Clade(branch_length=0.07112028, confidence=98),
#  Clade(branch_length=0.22589084, confidence=100),
#  Clade(branch_length=0.13594729, confidence=100),
#  Clade(branch_length=0.06609702, confidence=20),
#  Clade(branch_length=0.05444434, confidence=8),
#  Clade(branch_length=0.72645217, confidence=100),
#  Clade(branch_length=0.03136428, confidence=50),
#  Clade(branch_length=0.33011129, confidence=100),
#  Clade(branch_length=0.19994606, confidence=100),
#  Clade(branch_length=0.30371627, confidence=100),
#  Clade(branch_length=0.04785216, confidence=53),
#  Clade(branch_length=0.0222082, confidence=17),
#  Clade(branch_length=0.14308764, confidence=74),
#  Clade(branch_length=0.40950806, confidence=100),
#  Clade(branch_length=0.45064326, confidence=100),
#  Clade(branch_length=0.17583142, confidence=100),
#  Clade(branch_length=0.01816413, confidence=61),
#  Clade(branch_length=0.03802516, confidence=43),
#  Clade(branch_length=0.02765094, confidence=45),
#  Clade(branch_length=0.13016455, confidence=100),
#  Clade(branch_length=0.02538202, confidence=18),
#  Clade(branch_length=0.05603409, confidence=76),
#  Clade(branch_length=0.1868475, confidence=100),
#  Clade(branch_length=0.03174242, confidence=52),
#  Clade(branch_length=0.13931339, confidence=100),
#  Clade(branch_length=0.11808318, confidence=98),
#  Clade(branch_length=0.10203551, confidence=20),
#  Clade(branch_length=0.64579328, confidence=100),
#  Clade(branch_length=0.21883825, confidence=100),
#  Clade(branch_length=0.06668214, confidence=69),
#  Clade(branch_length=0.2698646, confidence=100),
#  Clade(branch_length=0.1949129, confidence=100),
#  Clade(branch_length=0.08183787, confidence=65),
#  Clade(branch_length=0.28748475, confidence=100),
#  Clade(branch_length=0.05526509, confidence=46),
#  Clade(branch_length=0.12407341, confidence=88),
#  Clade(branch_length=0.13294641, confidence=93),
#  Clade(branch_length=0.24639253, confidence=100),
#  Clade(branch_length=0.05430849, confidence=86),
#  Clade(branch_length=0.12209759, confidence=93),
#  Clade(branch_length=0.04418946, confidence=33),
#  Clade(branch_length=0.23152216, confidence=100),
#  Clade(branch_length=0.56023385, confidence=100),
#  Clade(branch_length=0.07145383, confidence=79),
#  Clade(branch_length=0.18186587, confidence=100),
#  Clade(branch_length=0.06402259, confidence=74),
#  Clade(branch_length=0.20022152, confidence=100),
#  Clade(branch_length=0.10237739, confidence=100),
#  Clade(branch_length=0.05350945, confidence=78),
#  Clade(branch_length=0.13154846, confidence=100),
#  Clade(branch_length=0.07124379, confidence=69),
#  Clade(branch_length=0.13328189, confidence=100),
#  Clade(branch_length=0.03266966, confidence=54),
#  Clade(branch_length=0.04157701, confidence=62),
#  Clade(branch_length=0.05405182, confidence=68),
#  Clade(branch_length=0.04809741, confidence=47),
#  Clade(branch_length=0.01424312, confidence=27),
#  Clade(branch_length=0.07542677, confidence=66),
#  Clade(branch_length=0.09428142, confidence=88),
#  Clade(branch_length=0.02354516, confidence=61),
#  Clade(branch_length=0.04146753, confidence=89),
#  Clade(branch_length=0.01578981, confidence=75),
#  Clade(branch_length=0.02037215, confidence=54),
#  Clade(branch_length=0.15353254, confidence=96),
#  Clade(branch_length=0.06077317, confidence=96),
#  Clade(branch_length=0.00927654, confidence=36),
#  Clade(branch_length=0.05154666, confidence=77),
#  Clade(branch_length=0.02210229, confidence=60),
#  Clade(branch_length=0.1051805, confidence=71),
#  Clade(branch_length=0.08391613, confidence=58),
#  Clade(branch_length=0.52621973, confidence=100),
#  Clade(branch_length=0.13639643, confidence=73),
#  Clade(branch_length=0.07607342, confidence=45),
#  Clade(branch_length=0.45228738, confidence=100),
#  Clade(branch_length=0.05606679, confidence=64),
#  Clade(branch_length=0.02273292, confidence=48),
#  Clade(branch_length=0.01447624, confidence=22),
#  Clade(branch_length=0.2291218, confidence=100),
#  Clade(branch_length=0.17530504, confidence=100),
#  Clade(branch_length=0.31857665, confidence=100),
#  Clade(branch_length=0.03587983, confidence=85),
#  Clade(branch_length=0.03108959, confidence=97),
#  Clade(branch_length=0.04494561, confidence=68),
#  Clade(branch_length=0.08877978, confidence=92),
#  Clade(branch_length=0.03055143, confidence=54),
#  Clade(branch_length=0.082868, confidence=95),
#  Clade(branch_length=0.09513066, confidence=99),
#  Clade(branch_length=0.16671617, confidence=99),
#  Clade(branch_length=0.06282499, confidence=93),
#  Clade(branch_length=0.22848984, confidence=100),
#  Clade(branch_length=0.0507503, confidence=66),
#  Clade(branch_length=0.12136445, confidence=100),
#  Clade(branch_length=0.0440698, confidence=72),
#  Clade(branch_length=0.11629511, confidence=97),
#  Clade(branch_length=0.10823408, confidence=100),
#  Clade(branch_length=0.12933419, confidence=100),
#  Clade(branch_length=0.03930514, confidence=58),
#  Clade(branch_length=0.06320371, confidence=97),
#  Clade(branch_length=0.0891399, confidence=99),
#  Clade(branch_length=0.03811178, confidence=42),
#  Clade(branch_length=0.05910297, confidence=75),
#  Clade(branch_length=0.10145747, confidence=100),
#  Clade(branch_length=0.05228421, confidence=73),
#  Clade(branch_length=0.2010807, confidence=100),
#  Clade(branch_length=0.09571864, confidence=99),
#  Clade(branch_length=0.00730273, confidence=24),
#  Clade(branch_length=0.02012075, confidence=27),
#  Clade(branch_length=0.02313749, confidence=58),
#  Clade(branch_length=0.03850236, confidence=51),
#  Clade(branch_length=0.05565194, confidence=68),
#  Clade(branch_length=0.05121455, confidence=86),
#  Clade(branch_length=0.10120958, confidence=100),
#  Clade(branch_length=0.11145014, confidence=100),
#  Clade(branch_length=0.05792847, confidence=92),
#  Clade(branch_length=0.18941967, confidence=100),
#  Clade(branch_length=0.04109555, confidence=96),
#  Clade(branch_length=0.02209363, confidence=38),
#  Clade(branch_length=0.05247435, confidence=93),
#  Clade(branch_length=0.08349806, confidence=87),
#  Clade(branch_length=0.033538, confidence=78),
#  Clade(branch_length=0.3180051, confidence=100),
#  Clade(branch_length=0.00858916, confidence=32),
#  Clade(branch_length=0.02292596, confidence=31),
#  Clade(branch_length=0.13484214, confidence=100),
#  Clade(branch_length=0.05038474, confidence=95),
#  Clade(branch_length=0.05477571, confidence=100),
#  Clade(branch_length=0.01152976, confidence=11),
#  Clade(branch_length=0.050044, confidence=75),
#  Clade(branch_length=0.02525682, confidence=66),
#  Clade(branch_length=0.12629712, confidence=100),
#  Clade(branch_length=0.0120048, confidence=91),
#  Clade(branch_length=0.06260005, confidence=61),
#  Clade(branch_length=0.32397498, confidence=100),
#  Clade(branch_length=0.38701208, confidence=100),
#  Clade(branch_length=0.0810025, confidence=57),
#  Clade(branch_length=0.04076536, confidence=16),
#  Clade(branch_length=0.03070329, confidence=18),
#  Clade(branch_length=0.08105026, confidence=54),
#  Clade(branch_length=0.29621101, confidence=100),
#  Clade(branch_length=0.04835033, confidence=41),
#  Clade(branch_length=0.14891603, confidence=100),
#  Clade(branch_length=0.19643425, confidence=100),
#  Clade(branch_length=0.04540938, confidence=66),
#  Clade(branch_length=0.00462338, confidence=32),
#  Clade(branch_length=0.02100577, confidence=70),
#  Clade(branch_length=0.41780845, confidence=100),
#  Clade(branch_length=0.0433454, confidence=50),
#  Clade(branch_length=0.39243697, confidence=100),
#  Clade(branch_length=0.11603223, confidence=81),
#  Clade(branch_length=0.04712183, confidence=57),
#  Clade(branch_length=0.03917258, confidence=46),
#  Clade(branch_length=0.05392693, confidence=56),
#  Clade(branch_length=0.06664029, confidence=29),
#  Clade(branch_length=0.02763342, confidence=17),
#  Clade(branch_length=0.30201291, confidence=100),
#  Clade(branch_length=0.03728852, confidence=86),
#  Clade(branch_length=0.09011252, confidence=59),
#  Clade(branch_length=0.09293028, confidence=90),
#  Clade(branch_length=0.35266982, confidence=100),
#  Clade(branch_length=0.25298038, confidence=100),
#  Clade(branch_length=0.04380615, confidence=45),
#  Clade(branch_length=0.05086701, confidence=86),
#  Clade(branch_length=0.08874023, confidence=100),
#  Clade(branch_length=0.03725861, confidence=74),
#  Clade(branch_length=0.08621815, confidence=100),
#  Clade(branch_length=0.19634093, confidence=100),
#  Clade(branch_length=0.25885453, confidence=100),
#  Clade(branch_length=0.19355786, confidence=100),
#  Clade(branch_length=0.0569986, confidence=73),
#  Clade(branch_length=0.05883893, confidence=81),
#  Clade(branch_length=0.18201875, confidence=100),
#  Clade(branch_length=0.0459922, confidence=36),
#  Clade(branch_length=0.09563182, confidence=96),
#  Clade(branch_length=0.12038749, confidence=100),
#  Clade(branch_length=0.23177874, confidence=100),
#  Clade(branch_length=0.02703994, confidence=90),
#  Clade(branch_length=0.0438671, confidence=61),
#  Clade(branch_length=0.02835072, confidence=52),
#  Clade(branch_length=0.06341573, confidence=94),
#  Clade(branch_length=0.04484661, confidence=71),
#  Clade(branch_length=0.06340641, confidence=96),
#  Clade(branch_length=0.05471863, confidence=96),
#  Clade(branch_length=0.03025494, confidence=49),
#  Clade(branch_length=0.05052775, confidence=69),
#  Clade(branch_length=0.03098959, confidence=8),
#  Clade(branch_length=0.05175132, confidence=26),
#  Clade(branch_length=0.18903683, confidence=97),
#  Clade(branch_length=0.18210028, confidence=99),
#  Clade(branch_length=0.03738011, confidence=49),
#  Clade(branch_length=0.04949755, confidence=25),
#  Clade(branch_length=0.25290896, confidence=100),
#  Clade(branch_length=0.06168115, confidence=62),
#  Clade(branch_length=0.06369793, confidence=84),
#  Clade(branch_length=0.03177285, confidence=33),
#  Clade(branch_length=0.1072676, confidence=100),
#  Clade(branch_length=0.09077649, confidence=100),
#  Clade(branch_length=0.1220637, confidence=100),
#  Clade(branch_length=0.17527735, confidence=100),
#  Clade(branch_length=0.06390713, confidence=100),
#  Clade(branch_length=0.02944473, confidence=59),
#  Clade(branch_length=0.03416727, confidence=16),
#  Clade(branch_length=0.03930985, confidence=21),
#  Clade(branch_length=0.03346048, confidence=25),
#  Clade(branch_length=0.30790679, confidence=97),
#  Clade(branch_length=0.06850348, confidence=52),
#  Clade(branch_length=0.08218354, confidence=60),
#  Clade(branch_length=0.12209656, confidence=83),
#  Clade(branch_length=0.28393613, confidence=100),
#  Clade(branch_length=0.11793153, confidence=99),
#  Clade(branch_length=0.07808669, confidence=100),
#  Clade(branch_length=0.06276704, confidence=59),
#  Clade(branch_length=0.13588413, confidence=100),
#  Clade(branch_length=0.03374924, confidence=45),
#  Clade(branch_length=0.04882719, confidence=94),
#  Clade(branch_length=0.12182031, confidence=82),
#  Clade(branch_length=0.23298289, confidence=96),
#  Clade(branch_length=0.04661725, confidence=64),
#  Clade(branch_length=0.07042482, confidence=67),
#  Clade(branch_length=0.19984718, confidence=100),
#  Clade(branch_length=0.18074248, confidence=99),
#  Clade(branch_length=0.06226973, confidence=88),
#  Clade(branch_length=0.04098589, confidence=76),
#  Clade(branch_length=0.08658907, confidence=36),
#  Clade(branch_length=0.44829011, confidence=100),
#  Clade(branch_length=0.07909879, confidence=89),
#  Clade(branch_length=0.05404672, confidence=22),
#  Clade(branch_length=0.03495785, confidence=4),
#  Clade(branch_length=0.08350136, confidence=59),
#  Clade(branch_length=0.06087448, confidence=75),
#  Clade(branch_length=0.27101043, confidence=99),
#  Clade(branch_length=0.36554874, confidence=100),
#  Clade(branch_length=0.06020803, confidence=67),
#  Clade(branch_length=0.04108994, confidence=46),
#  Clade(branch_length=0.04602928, confidence=13),
#  Clade(branch_length=0.34019537, confidence=99),
#  Clade(branch_length=0.060495, confidence=41),
#  Clade(branch_length=0.25576748, confidence=98),
#  Clade(branch_length=0.03962256, confidence=73),
#  Clade(branch_length=0.03923553, confidence=15),
#  Clade(branch_length=0.07558499, confidence=13),
#  Clade(branch_length=0.38517505, confidence=100),
#  Clade(branch_length=0.05197095, confidence=55),
#  Clade(branch_length=0.23460072, confidence=100),
#  Clade(branch_length=0.09679809, confidence=15),
#  Clade(branch_length=0.27114443, confidence=100),
#  Clade(branch_length=0.91689538, confidence=100),
#  Clade(branch_length=0.32995243, confidence=100),
#  Clade(branch_length=0.10469494, confidence=100),
#  Clade(branch_length=0.07805608, confidence=83),
#  Clade(branch_length=0.02548633, confidence=77),
#  Clade(branch_length=0.0671756, confidence=99),
#  Clade(branch_length=0.01438144, confidence=43),
#  Clade(branch_length=0.01761227, confidence=54),
#  Clade(branch_length=0.14099263, confidence=61),
#  Clade(branch_length=0.14485367, confidence=64),
#  Clade(branch_length=0.1568745, confidence=100),
#  Clade(branch_length=0.03733681, confidence=18),
#  Clade(branch_length=0.0297923, confidence=21),
#  Clade(branch_length=0.03788753, confidence=22),
#  Clade(branch_length=0.06802781, confidence=65),
#  Clade(branch_length=0.06319762, confidence=91),
#  Clade(branch_length=0.00821678, confidence=15),
#  Clade(branch_length=0.04113866, confidence=34),
#  Clade(branch_length=0.15553443, confidence=93),
#  Clade(branch_length=0.22429097, confidence=94),
#  Clade(branch_length=0.15232551, confidence=100),
#  Clade(branch_length=0.39433242, confidence=100),
#  Clade(branch_length=0.12657535, confidence=69),
#  Clade(branch_length=0.41215099, confidence=100),
#  Clade(branch_length=0.09112185, confidence=65),
#  Clade(branch_length=0.18777039, confidence=100),
#  Clade(branch_length=0.20313105, confidence=100),
#  Clade(branch_length=0.10010101, confidence=64),
#  Clade(branch_length=0.06328197, confidence=66),
#  Clade(branch_length=0.2298769, confidence=100),
#  Clade(branch_length=0.12373568, confidence=100),
#  Clade(branch_length=0.04087686, confidence=38),
#  Clade(branch_length=0.14288216, confidence=100),
#  Clade(branch_length=0.0644991, confidence=41),
#  Clade(branch_length=0.16491621, confidence=100),
#  Clade(branch_length=0.19173354, confidence=100),
#  Clade(branch_length=0.05850576, confidence=30),
#  Clade(branch_length=0.47919549, confidence=100),
#  Clade(branch_length=0.14442107, confidence=100),
#  Clade(branch_length=0.07176727, confidence=95),
#  Clade(branch_length=0.04284016, confidence=36),
#  Clade(branch_length=0.04033935, confidence=51),
#  Clade(branch_length=0.09170564, confidence=82),
#  Clade(branch_length=0.05013503, confidence=85),
#  Clade(branch_length=0.11398502, confidence=100),
#  Clade(branch_length=0.18733651, confidence=100),
#  Clade(branch_length=0.1520968, confidence=100),
#  Clade(branch_length=0.09793099, confidence=100),
#  Clade(branch_length=0.07702161, confidence=95),
#  Clade(branch_length=0.05307998, confidence=91),
#  Clade(branch_length=0.07620772, confidence=87),
#  Clade(branch_length=0.05279086, confidence=55),
#  Clade(branch_length=0.10198002, confidence=100),
#  Clade(branch_length=0.12161206, confidence=100),
#  Clade(branch_length=0.02030167, confidence=12),
#  Clade(branch_length=0.1998499, confidence=100),
#  Clade(branch_length=0.0120245, confidence=6),
#  Clade(branch_length=0.02412203, confidence=13),
#  Clade(branch_length=0.03137716, confidence=53),
#  Clade(branch_length=0.20835573, confidence=100),
#  Clade(branch_length=0.04911685, confidence=88),
#  Clade(branch_length=0.04209197, confidence=85),
#  Clade(branch_length=0.05490494, confidence=93),
#  Clade(branch_length=0.11586298, confidence=100),
#  Clade(branch_length=0.05911557, confidence=71),
#  Clade(branch_length=0.12916581, confidence=100),
#  Clade(branch_length=0.04276698, confidence=43),
#  Clade(branch_length=0.13309803, confidence=100),
#  Clade(branch_length=0.15090264, confidence=100),
#  Clade(branch_length=0.05953907, confidence=69),
#  Clade(branch_length=0.10132442, confidence=99),
#  Clade(branch_length=0.20787615, confidence=100),
#  Clade(branch_length=0.01301536, confidence=49),
#  Clade(branch_length=0.25993869, confidence=100),
#  Clade(branch_length=0.0874816, confidence=94),
#  Clade(branch_length=0.05839421, confidence=77),
#  Clade(branch_length=0.00823034, confidence=4),
#  Clade(branch_length=0.04968588, confidence=29),
#  Clade(branch_length=0.07434025, confidence=100),
#  Clade(branch_length=0.0738046, confidence=96),
#  Clade(branch_length=0.13973319, confidence=100),
#  Clade(branch_length=0.06042321, confidence=80),
#  Clade(branch_length=0.04176557, confidence=70),
#  Clade(branch_length=0.04706835, confidence=29),
#  Clade(branch_length=0.06063196, confidence=50),
#  Clade(branch_length=0.15119382, confidence=100),
#  Clade(branch_length=0.03372241, confidence=23),
#  Clade(branch_length=0.0735545, confidence=62),
#  Clade(branch_length=0.0459951, confidence=23),
#  Clade(branch_length=0.25024719, confidence=100),
#  Clade(branch_length=0.05194193, confidence=99),
#  Clade(branch_length=0.02793238, confidence=28),
#  Clade(branch_length=0.03634824, confidence=57),
#  Clade(branch_length=0.03109438, confidence=38),
#  Clade(branch_length=0.1042633, confidence=99),
#  Clade(branch_length=0.2329265, confidence=100),
#  Clade(branch_length=0.02163009, confidence=6),
#  Clade(branch_length=0.1169691, confidence=100),
#  Clade(branch_length=0.07859255, confidence=100),
#  Clade(branch_length=0.04611713, confidence=97),
#  Clade(branch_length=0.02346397, confidence=80),
#  Clade(branch_length=0.03014669, confidence=79),
#  Clade(branch_length=0.03363421, confidence=16),
#  Clade(branch_length=0.02377215, confidence=48),
#  Clade(branch_length=0.2092447, confidence=100),
#  Clade(branch_length=0.08621019, confidence=96),
#  Clade(branch_length=0.12220288, confidence=100),
#  Clade(branch_length=0.14047518, confidence=98),
#  Clade(branch_length=0.03742298, confidence=20),
#  Clade(branch_length=0.02659413, confidence=16),
#  Clade(branch_length=0.02127692, confidence=6),
#  Clade(branch_length=0.23209864, confidence=100),
#  Clade(branch_length=0.01993052, confidence=16),
#  Clade(branch_length=0.03433546, confidence=17),
#  Clade(branch_length=0.02393602, confidence=28),
#  Clade(branch_length=0.0340787, confidence=52),
#  Clade(branch_length=0.08654432, confidence=99),
#  Clade(branch_length=0.09584641, confidence=100),
#  Clade(branch_length=0.0361887, confidence=67),
#  Clade(branch_length=0.20297725, confidence=100),
#  Clade(branch_length=0.16456643, confidence=100),
#  Clade(branch_length=0.04197989, confidence=92),
#  Clade(branch_length=0.09938029, confidence=100),
#  Clade(branch_length=0.08372711, confidence=49),
#  Clade(branch_length=0.05273489, confidence=94),
#  Clade(branch_length=0.0851319, confidence=98),
#  Clade(branch_length=0.15912357, confidence=100),
#  Clade(branch_length=0.06090473, confidence=92),
#  Clade(branch_length=0.09381624, confidence=95),
#  Clade(branch_length=0.11947308, confidence=100),
#  Clade(branch_length=0.26097916, confidence=100),
#  Clade(branch_length=0.0285115, confidence=68),
#  Clade(branch_length=0.02301549, confidence=85),
#  Clade(branch_length=0.03054181, confidence=81),
#  Clade(branch_length=0.03945906, confidence=76),
#  Clade(branch_length=0.06594056, confidence=94),
#  Clade(branch_length=0.15596609, confidence=100),
#  Clade(branch_length=0.1668149, confidence=100),
#  Clade(branch_length=0.02257626, confidence=45),
#  Clade(branch_length=0.04251356, confidence=89),
#  Clade(branch_length=0.10557995, confidence=100),
#  Clade(branch_length=0.06759244, confidence=93),
#  Clade(branch_length=0.04511272, confidence=62),
#  Clade(branch_length=0.04902453, confidence=85),
#  Clade(branch_length=0.02588304, confidence=50),
#  Clade(branch_length=0.09668881, confidence=100),
#  Clade(branch_length=0.17350327, confidence=100),
#  Clade(branch_length=0.04029146, confidence=83),
#  Clade(branch_length=0.02659897, confidence=51),
#  Clade(branch_length=0.06441578, confidence=96),
#  Clade(branch_length=0.04180765, confidence=59),
#  Clade(branch_length=0.09951377, confidence=98),
#  Clade(branch_length=0.13556999, confidence=99),
#  Clade(branch_length=0.07505179, confidence=98),
#  Clade(branch_length=0.10941769, confidence=100),
#  Clade(branch_length=0.03595063, confidence=51),
#  Clade(branch_length=0.06956144, confidence=95),
#  Clade(branch_length=0.20045133, confidence=100),
#  Clade(branch_length=0.03614197, confidence=84),
#  Clade(branch_length=0.03742434, confidence=32),
#  Clade(branch_length=0.00962296, confidence=4),
#  Clade(branch_length=0.0179071, confidence=4),
#  Clade(branch_length=0.03610206, confidence=29),
#  Clade(branch_length=0.02703381, confidence=31),
#  Clade(branch_length=0.15365859, confidence=100),
#  Clade(branch_length=0.06235258, confidence=35),
#  Clade(branch_length=0.14118897, confidence=100),
#  Clade(branch_length=0.06201948, confidence=87),
#  Clade(branch_length=0.24033782, confidence=100),
#  Clade(branch_length=0.05311595, confidence=98),
#  Clade(branch_length=0.03265034, confidence=33),
#  Clade(branch_length=0.24601674, confidence=100),
#  Clade(branch_length=0.03350178, confidence=58),
#  Clade(branch_length=0.03363177, confidence=32),
#  Clade(branch_length=0.0415536, confidence=37),
#  Clade(branch_length=0.31469438, confidence=100),
#  Clade(branch_length=0.04272892, confidence=11),
#  Clade(branch_length=0.03719991, confidence=17),
#  Clade(branch_length=0.07536416, confidence=82),
#  Clade(branch_length=0.04076366, confidence=33),
#  Clade(branch_length=0.15945903, confidence=100),
#  Clade(branch_length=0.09716199, confidence=100),
#  Clade(branch_length=0.08377469, confidence=100),
#  Clade(branch_length=0.01668898, confidence=20),
#  Clade(branch_length=0.03731896, confidence=42),
#  Clade(branch_length=0.04997284, confidence=90),
#  Clade(branch_length=0.02793935, confidence=58),
#  Clade(branch_length=0.04304778, confidence=77),
#  Clade(branch_length=0.11379712, confidence=100),
#  Clade(branch_length=0.09841494, confidence=100),
#  Clade(branch_length=0.03449077, confidence=70),
#  Clade(branch_length=0.10375742, confidence=100),
#  Clade(branch_length=0.12584393, confidence=100),
#  Clade(branch_length=0.13110789, confidence=100),
#  Clade(branch_length=0.1674982, confidence=100),
#  Clade(branch_length=0.01908042, confidence=66),
#  Clade(branch_length=0.03385132, confidence=44),
#  Clade(branch_length=0.03711219, confidence=29),
#  Clade(branch_length=0.27159299, confidence=100),
#  Clade(branch_length=0.07454147, confidence=99),
#  Clade(branch_length=0.13748513, confidence=100),
#  Clade(branch_length=0.04461196, confidence=50),
#  Clade(branch_length=0.04153384, confidence=48),
#  Clade(branch_length=0.07466832, confidence=99),
#  Clade(branch_length=0.12368436, confidence=100),
#  Clade(branch_length=0.05684097, confidence=93),
#  Clade(branch_length=0.05895329, confidence=96),
#  Clade(branch_length=0.11433894, confidence=100),
#  Clade(branch_length=0.03819989, confidence=73),
#  Clade(branch_length=0.05487855, confidence=71),
#  Clade(branch_length=0.04652543, confidence=54),
#  Clade(branch_length=0.01909823, confidence=35),
#  Clade(branch_length=0.1347737, confidence=100),
#  Clade(branch_length=0.11826516, confidence=100),
#  Clade(branch_length=0.12535122, confidence=100),
#  Clade(branch_length=0.04868993, confidence=80),
#  Clade(branch_length=0.02613428, confidence=56),
#  Clade(branch_length=0.03179886, confidence=75),
#  Clade(branch_length=0.08305306, confidence=100),
#  Clade(branch_length=0.0663194, confidence=100),
#  Clade(branch_length=0.02795714, confidence=82),
#  Clade(branch_length=0.10339154, confidence=100),
#  Clade(branch_length=0.06517484, confidence=100),
#  Clade(branch_length=0.04780366, confidence=99),
#  Clade(branch_length=0.01774383, confidence=99),
#  Clade(branch_length=0.01976893, confidence=91),
#  Clade(branch_length=0.01393588, confidence=89),
#  Clade(branch_length=0.08379319, confidence=10),
#  Clade(branch_length=0.16234754, confidence=60),
#  Clade(branch_length=0.68357832, confidence=100),
#  Clade(branch_length=0.31479008, confidence=100),
#  Clade(branch_length=0.21087398, confidence=94),
#  Clade(branch_length=0.09166979, confidence=65),
#  Clade(branch_length=0.50958292, confidence=100),
#  Clade(branch_length=0.43306763, confidence=100),
#  Clade(branch_length=0.03682161, confidence=37),
#  Clade(branch_length=0.02042306, confidence=42),
#  Clade(branch_length=0.08720775, confidence=43),
#  Clade(branch_length=0.39623131, confidence=100),
#  Clade(branch_length=0.04841923, confidence=37),
#  Clade(branch_length=0.0279363, confidence=25),
#  Clade(branch_length=0.29120512, confidence=100),
#  Clade(branch_length=0.07129129, confidence=37),
#  Clade(branch_length=0.02717225, confidence=19),
#  Clade(branch_length=0.28258026, confidence=100),
#  Clade(branch_length=0.164871, confidence=100),
#  Clade(branch_length=0.07390982, confidence=89),
#  Clade(branch_length=0.02739983, confidence=35),
#  Clade(branch_length=0.11993854, confidence=89),
#  Clade(branch_length=0.10844097, confidence=95),
#  Clade(branch_length=0.07938924, confidence=78),
#  Clade(branch_length=0.48547769, confidence=100),
#  Clade(branch_length=0.05566104, confidence=61),
#  Clade(branch_length=0.28993981, confidence=100),
#  Clade(branch_length=0.29893314, confidence=100),
#  Clade(branch_length=0.05696467, confidence=37),
#  Clade(branch_length=0.10574346, confidence=94),
#  Clade(branch_length=0.04278676, confidence=78),
#  Clade(branch_length=0.03740291, confidence=76),
#  Clade(branch_length=0.03300369, confidence=89),
#  Clade(branch_length=0.02963976, confidence=85),
#  Clade(branch_length=0.1402413, confidence=37),
#  Clade(branch_length=0.13921052, confidence=63),
#  Clade(branch_length=0.29754658, confidence=97),
#  ...]

# %%
cladeA=mrca.get_terminals()
#print(len(cladeA))
# Out:
# 48

# %%
clade_A=[]
for i in range(0,len(cladeA)):
    clade_A.append(cladeA[i].name)
    #print(cladeA[i].name)
print(clade_A)
# Out:
# ['LhOr59', 'CfOr198', 'PbOr175', 'HsOr205', 'PbOr165CTE', 'PbOr166', 'CfOr192', 'PbOr163', 'LhOr47FIX', 'HsOr202', 'PbOr173', 'LhOr58', 'LhOr57', 'PbOr172', 'CfOr197', 'HsOr192', 'HsOr193', 'HsOr206', 'HsOr207', 'HsOr208', 'PbOr168', 'CfOr199', 'LhOr50', 'LhOr51', 'HsOr201', 'LhOr48', 'PbOr164FIX', 'LhOr49', 'PbOr167', 'HsOr199', 'AmOr169', 'AmOr168', 'AmOr170', 'HsOr194', 'CfOr196', 'LhOr54', 'LhOr56', 'HsOr200', 'HsOr197', 'HsOr196', 'HsOr195', 'HsOr198', 'LhOr55', 'CfOr193', 'LhOr52', 'CfOr195', 'CfOr194', 'PbOr170']

# %%
def clade_siblings(relative1,relative2,clade_name):
    mcra=tree.common_ancestor({"name":"%s"%relative1},{"name":"%s"%relative2})
    clade_name=[]
    clade_of_interest=mcra.get_terminals()

    for i in range(0,len(clade_of_interest)):
        clade_name.append(clade_of_interest[i].name)
    return(clade_name)

# %%
#mrca = tree.common_ancestor({"name": "HsOr188"}, {"name": "LhOr210"})
print(clade_siblings("HsOr188","LhOr210","Clade_B"))
clade_B=clade_siblings("HsOr188","LhOr210","Clade_B")
# Out:
# ['HsOr188', 'CfOr188', 'PbOr151', 'AmOr119', 'LhOr210']

# %%
clade_C=clade_siblings("AmOr116","HsOr219","Clade_C")
print(clade_C)
# Out:
# ['AmOr116', 'CfOr217', 'PbOr197', 'LhOr224', 'HsOr219']

# %%
clade_D=clade_siblings("CfOr262","NvOr121PSE","Clade_D")
print(clade_D)
# Out:
# ['NvOr121PSE', 'NvOr122', 'NvOr125', 'NvOr118', 'NvOr117', 'NvOr119', 'NvOr124', 'NvOr126', 'NvOr127INT', 'NvOr128', 'LhOr227', 'LhOr228', 'HsOr181', 'PbOr227', 'HsOr183', 'HsOr182', 'PbOr229', 'CfOr263', 'LhOr229', 'LhOr231', 'CfOr258', 'PbOr230', 'LhOr230', 'CfOr259', 'CfOr261', 'CfOr262']

# %%
clade_E=clade_siblings("NvOr80","LhOr135","Clade_E")
print(clade_E)
# Out:
# ['NvOr80', 'NvOr98', 'NvOr103', 'NvOr105', 'NvOr99', 'NvOr100', 'NvOr102', 'NvOr101', 'NvOr113', 'NvOr114', 'NvOr115', 'NvOr112PSE', 'NvOr106', 'NvOr108PSE', 'NvOr109PSE', 'NvOr107', 'NvOr111', 'NvOr110', 'NvOr93', 'NvOr90PSE', 'NvOr94', 'NvOr92', 'NvOr96', 'NvOr84INT', 'NvOr85', 'NvOr97CTE', 'NvOr87', 'NvOr86', 'NvOr88', 'NvOr89', 'AmOr73', 'CfOr218', 'LhOr225', 'PbOr198FIX', 'PbOr199FIX', 'PbOr200', 'PbOr201', 'LhOr226', 'HsOr242', 'HsOr240', 'HsOr241', 'CfOr231', 'CfOr229', 'CfOr230', 'CfOr232', 'NvOr82', 'NvOr81', 'LhOr138', 'LhOr137', 'HsOr239', 'LhOr139', 'PbOr202FIX', 'CfOr233', 'CfOr251', 'CfOr234', 'CfOr250', 'HsOr235', 'HsOr234', 'HsOr236', 'HsOr238', 'CfOr257', 'HsOr226', 'HsOr227', 'HsOr237', 'HsOr230', 'HsOr231', 'HsOr228', 'HsOr229', 'HsOr232', 'HsOr233', 'PbOr206FIX', 'CfOr255', 'CfOr249', 'LhOr140FIX', 'CfOr252', 'PbOr203', 'CfOr254', 'LhOr142', 'LhOr141', 'PbOr207', 'LhOr145', 'LhOr143', 'LhOr144', 'AmOr70', 'AmOr71', 'AmOr72', 'AmOr68', 'AmOr69', 'LhOr123FIX', 'CfOr243', 'CfOr244', 'LhOr124', 'LhOr125', 'CfOr245', 'PbOr214', 'PbOr213', 'CfOr242', 'LhOr122', 'CfOr239', 'LhOr119', 'LhOr118', 'CfOr238', 'PbOr209', 'PbOr210', 'CfOr236', 'LhOr117', 'CfOr241', 'LhOr121', 'PbOr212', 'LhOr120FIX', 'CfOr240', 'PbOr211JF', 'LhOr126', 'PbOr215', 'CfOr246', 'CfOr247', 'CfOr248', 'LhOr128', 'CfOr226', 'PbOr217FIX', 'LhOr127', 'CfOr227', 'CfOr228', 'CfOr224', 'HsOr220', 'LhOr129', 'HsOr221', 'CfOr222', 'LhOr130', 'CfOr223', 'LhOr131', 'PbOr221', 'PbOr219', 'PbOr220', 'CfOr225', 'PbOr218', 'HsOr224', 'LhOr132', 'PbOr222FIX', 'CfOr219', 'CfOr220', 'HsOr225', 'LhOr133', 'PbOr223JOI', 'LhOr136', 'PbOr225', 'HsOr223', 'PbOr224JOI', 'LhOr134FIX', 'LhOr135']

# %%
#loop through a list and make the clades in alphabelical order
#call clade_siblings
ant_clades={
    "Clade_A": ["PbOr170","LhOr59"],
    "Clade_B": ["HsOr188","LhOr210"],
    "Clade_C": ["AmOr116", "HsOr219"],
    "Clade_D": ["NvOr121PSE", "CfOr262"],
    "Clade_E": ["NvOr98","LhOr135"],
    "Clade_F": ["AmOr171","NvOr263"],
    "Clade_G": ["NvOr45","PbOr195JF"],
    "Clade_H": ["NvOr44","PbOr190FIX"],
    "Clade_I": ["NvOr296","PbOr145"],
    "Clade_J": ["PbOr154","AmOr84"],
    "Clade_K": ["AmOr1","PbOr3"],
    "Clade_L": ["NvOr8","PbOr12"],
    "Clade_M": ["LhOr146","PbOr56FIX"],
    "Clade_N": ["NvOr61","LhOr155"],
    "Clade_O": ["NvOr60","CfOr52"],
    "Clade_P": ["AmOr65","CfOr101"],
    "Clade_Q": ["AmOr160","HsOr187"],
    "Clade_R": ["HsOr179","LhOr207"],
    "Clade_S": ["PbOr149", "NvOr288"],
    "Clade_T": ["NvOr25", "HsOr86"],
    "Clade_U": ["NvOr38", "LhOr180FN"],
    "Clade_V": ["NvOr64","HsOr127"]
}
def make_clade_lists(clade_dict):
    clade_members={}
    for key,value in clade_dict.items():
        clade_name="clade_"+key.split("_")[1]
        clade_members[clade_name]=clade_siblings(value[0],value[1],key)
        #print(clade_name)
        #clade_siblings(value[0],value[1],key)
    return clade_members
clade_members=make_clade_lists(ant_clades)
        
#print(clade_members["clade_V"])
# Out:
# ['NvOr64', 'NvOr65', 'NvOr62', 'NvOr71', 'NvOr72', 'NvOr66', 'NvOr67', 'NvOr68', 'NvOr69', 'AmOr163', 'AmOr164FIX', 'AmOr118', 'LhOr71', 'PbOr104', 'HsOr164', 'HsOr166', 'HsOr165', 'PbOr105FIX', 'CfOr186', 'HsOr163', 'LhOr72', 'AmOr167JOI', 'CfOr185', 'HsOr162', 'PbOr106', 'LhOr73', 'AmOr165FIX', 'AmOr166JOI', 'PbOr120', 'HsOr146', 'PbOr121', 'CfOr175', 'LhOr94', 'LhOr95', 'HsOr160', 'LhOr75', 'PbOr108', 'CfOr183', 'HsOr156', 'LhOr78', 'PbOr111', 'PbOr112', 'HsOr157', 'HsOr158', 'CfOr181', 'LhOr77', 'PbOr110', 'HsOr159', 'LhOr76', 'CfOr182', 'PbOr109', 'HsOr155', 'LhOr79', 'CfOr179', 'CfOr180', 'LhOr80', 'CfOr178', 'HsOr154', 'PbOr114', 'HsOr153', 'HsOr148', 'HsOr152', 'HsOr151', 'HsOr149', 'HsOr150', 'CfOr176', 'PbOr115', 'PbOr116', 'PbOr118', 'PbOr117FI', 'LhOr89', 'LhOr84', 'LhOr83', 'LhOr82', 'LhOr87', 'LhOr91', 'LhOr81', 'LhOr86', 'LhOr85', 'LhOr92', 'HsOr161', 'PbOr107', 'CfOr184', 'LhOr74', 'PbOr122FIX', 'LhOr96', 'CfOr174', 'HsOr145', 'CfOr148', 'LhOr116', 'HsOr123', 'PbOr143', 'HsOr142', 'HsOr144', 'CfOr172', 'LhOr97', 'PbOr125', 'CfOr173', 'PbOr123FIX', 'PbOr124FIX', 'CfOr161', 'CfOr162', 'CfOr167', 'CfOr166', 'CfOr170', 'CfOr168', 'CfOr169', 'CfOr171', 'CfOr165', 'CfOr163', 'CfOr164', 'CfOr158', 'PbOr128', 'LhOr100', 'HsOr135', 'HsOr136', 'HsOr141', 'HsOr139', 'HsOr137', 'HsOr138', 'LhOr98', 'LhOr99', 'CfOr159', 'CfOr160', 'PbOr126FIX', 'PbOr127', 'HsOr133', 'LhOr102', 'PbOr130', 'PbOr131', 'LhOr104', 'LhOr103', 'HsOr132', 'HsOr131', 'HsOr167', 'HsOr168', 'HsOr134', 'PbOr129JF', 'LhOr101', 'CfOr157', 'CfOr156', 'CfOr154', 'CfOr155', 'CfOr152', 'PbOr132FI', 'LhOr105FIX', 'LhOr106FIX', 'LhOr107FIX', 'HsOr169', 'HsOr170', 'CfOr151', 'LhOr108', 'PbOr133', 'PbOr142FIX', 'PbOr144', 'LhOr113', 'LhOr114', 'LhOr115', 'CfOr143', 'CfOr141', 'CfOr142', 'CfOr147', 'CfOr144', 'CfOr145', 'CfOr146', 'HsOr124', 'HsOr130', 'HsOr125', 'HsOr128', 'HsOr129', 'HsOr171', 'HsOr173', 'HsOr174', 'HsOr126', 'HsOr127', 'LhOr112', 'PbOr141', 'CfOr140', 'HsOr175', 'HsOr176', 'LhOr111', 'CfOr139', 'PbOr139', 'PbOr140', 'PbOr138', 'LhOr110', 'CfOr149', 'CfOr153', 'LhOr109', 'CfOr150', 'PbOr134', 'PbOr135', 'PbOr136FIX', 'PbOr137']

# %%
#create a second tree

# %%
#loop through the clades of second tree

# %%
#compare the members of each clade
    #extract the ants from each clade 
    #extract the bees from each clade
    #extract wasps from each clade
        #see if the ants are in both lists
            #percentage that is in both
    #return the percent matching that is in each clade
